# %% [markdown]
# # PREDICTION: Deep Learning Forecasting with Feature Selection
#
# In this section, we implement and evaluate deep learning models to predict diagnostic activity over time, based on the selected set of input features derived from previous correlation and VIF analyses. The objective is to assess the effectiveness of using carefully filtered, non-redundant variables in time-series forecasting tasks within the primary care setting.
#
# Building on the previous steps — where redundant diagnoses were removed to ensure interpretability and reduce multicollinearity — we now train neural network architectures that can capture temporal dependencies and complex non-linear relationships in the data.
#
# This phase involves:
#
# - 1. Model Definition: Selection and configuration of a deep learning architecture (e.g., LSTM, GRU, or Transformer) suitable for univariate or multivariate time-series prediction.
#
# - 2. Training & Evaluation: Execution of training pipelines with the filtered feature set, and performance evaluation using appropriate metrics (e.g., MAE, RMSE, R²) on both training and validation sets.
#
# - 3. Forecasting Across Horizons: The models are tested on different prediction horizons to understand their robustness and sensitivity to time-window configuration.
#
# - 4. Comparison with Baselines: Results are compared against baseline models (e.g., naive persistence or linear regression) to quantify the added value of using deep learning with feature selection.
#
# This strategy aims to demonstrate that simpler yet informative inputs, when paired with powerful predictive models, can offer accurate and actionable forecasts — potentially supporting early-warning systems and demand planning in healthcare.

# %%
# no warnings
import warnings
warnings.filterwarnings('ignore')
# no logging
import logging
logging.disable(logging.CRITICAL)


import pandas as pd
import numpy as np
import math
import seaborn as sns
import sys
import time
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import pydot
import graphviz

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from statsmodels.tsa.seasonal import seasonal_decompose

import scipy
import scipy.stats
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch.optim as optim

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
# Set random seed for reproducibility
tf.random.set_seed(1234)
from keras import backend as K
from keras.models import Model, Sequential

# %% [markdown]
# ## 0. DATA RENDERING FUNCTIONS

# %%
# smoother function ---------------------------------
#       (revisar --> rolling(funció per fer-ho més fàcil))
def smoother(df,window_size):
    smoothed = {}
    for column in df.columns:
        if column != 'visi_data_visita':
            column_list = []
            for i in range(len(df)):
                if i == 0:
                    column_list.append(df[column].iloc[0])
                elif i < window_size:
                    column_list.append(df[column].iloc[:i+1].mean())
                else:
                    column_list.append(df[column].iloc[i-window_size:i+1].mean())
            smoothed[column] = column_list

    smoothed = pd.DataFrame.from_dict(smoothed)
    smoothed.set_index(df.index, inplace=True)
    return smoothed

# plot example 10 diags -------------------------
def plot_example(df, title):
    """
    Randomly selects and plots 10 time series from a DataFrame.
    
    Parameters:
    - df (pd.DataFrame): Time-indexed DataFrame with multiple columns (e.g. diagnostics).
    - title (str): Title for the plot.
    """
    # Randomly sample 10 columns
    sampled_cols = np.random.choice(df.columns, size=10, replace=False)
    dff = df[sampled_cols].copy()

    # Add date column
    dff["date"] = dff.index

    # Melt and plot
    sns.set(rc={'figure.figsize': (20, 8)})
    sns.lineplot(
        data=dff.melt(id_vars=['date']),
        x='date', y='value', hue='variable'
    ).set(title=title)

    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# plot example 10 diags -------------------------
def ploter(df,title,n,code):
    # PLOT RAW DATA (example 10 diags)
    cols = list(df.columns)[0:n]
    cols.append(code)
    dff = df[cols]
    dff["date"] = dff.index
    sns.set(rc={'figure.figsize':(20,8)})
    sns.lineplot(data=dff.replace('nan', float('nan')).melt(id_vars=['date']),x='date', y='value', hue='variable').set(title=title)

# %%
# RAW DATA --------------------------------------------------------------
df = pd.read_csv('synthetic_timeseries.csv', index_col=0)
df.index = pd.date_range(start="2010-01-01", periods=len(df), freq="D")
df = df.clip(lower=0)

window_size = 14
smoothed = smoother(df, window_size)

smoothed_scaled = (smoothed-smoothed.min())/(smoothed.max()-smoothed.min()) # normalize df

smoothed = smoothed_scaled

# %%
# SMOOTHED DATA --------------------------------------------------------
window_size = 30
# ----------------------------------------------------------------------
plot_example(smoothed,"SMOOTHED (example 10 ts)")

# %% [markdown]
# # DEEP LEARNING LAYER

# %% [markdown]
# ## 0. NEEDED FUNCTIONS

# %%
# Split the time series into chunk of the correct size. 
def split_sequence(sequence, look_back, forecast_horizon):
    X, y = list(), list()
    for i in range(len(sequence)): 
        lag_end = i + look_back
        forecast_end = lag_end + forecast_horizon
        if forecast_end > len(sequence):
            break
        seq_x, seq_y = sequence[i:lag_end], sequence[lag_end:forecast_end]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


# The used callbacks while compiling the models are the following. ModelCheckpoint is to save the model(weights) 
# at certain frequencies. EarlyStopping is used for stopping the progress if the monitored evaluation metric is 
# no longer improved. ReduceLROnPlateau is for decreasing the learning rate when the monitored metric has stopped 
# improving.
checkpoint_filepath = '../callbacks/best_model.keras'

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

early_stopping_callback = EarlyStopping(
    monitor='val_loss',
    min_delta=0.005,
    patience=10,
    mode='min'
)

rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, mode='min', patience=3, min_lr=0.001)


# transform data back to the original scale to evaluate the forecast. 
# We might simply utilize the following method. 
def inverse_transform(y_test, yhat):
    
    y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
    y_test_inverse = scaler.inverse_transform(y_test_reshaped)
    y_test_inverse = y_test_inverse.reshape(y_test.shape[0], -1)[:, :-1] #last col
    
    yhat_reshaped = yhat.reshape(-1, yhat.shape[-1]) 
    yhat_inverse = scaler.inverse_transform(yhat_reshaped)
    yhat_inverse = yhat_inverse.reshape(yhat.shape[0], -1)[:, :-1]
    
    return y_test_inverse, yhat_inverse

# To evaluate the forecast: mean square error(mse), mean absolute error(mae), 
# and mean absolute percentage error(mape) 
def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError() 
    mae = mae_(y_test_inverse,yhat_inverse)
    print('mae:', mae)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)
    
def get_results(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError() 
    mae = mae_(y_test_inverse,yhat_inverse)
    mse = mse_(y_test_inverse,yhat_inverse)
    mape = mape_(y_test_inverse,yhat_inverse)

    return mae, mse, mape

# plot model results ........................................................
def plt_model(y_test_inverse,yhat_inverse, model):
    plt.figure(figsize=(20, 10))
    plt.plot(pd.DataFrame(y_test_inverse)[[col_idx]], label='True Values')
    plt.plot(pd.DataFrame(yhat_inverse)[[col_idx]], label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.title('Real vs. Predicted Values // MODEL: '+model)
    plt.legend()
    plt.show()

# %% [markdown]
# ## 1. MODELS
#
# Layers:
# - *TimeDistributed layer*: is a kind of wrapper and expects another layer as an argument. It applies this layer to every temporal slice of input and therefore allows to build models that have one-to-many, many-to-many architectures. Similarly, it expects the input at least as 3 dimensions. (https://stackoverflow.com/questions/51749404/how-to-connect-lstm-layers-in-keras-repeatvector-or-return-sequence-true)
#
# - *RepeatVector*: basically repeats inputs n times. In other words, it increases the dimension of the output shape by 1. (https://github.com/keras-team/keras/issues/1029)
#
# #### 1.1. GRU architecture
#
# #### 1.1. LSTM architecture
#
# #### 1.1. Bi-directional LSTM architecture
#
# #### 1.1. Encoder-Decoder LSTM architecture
# - RNN Encoder-Decoder, consists of two recurrent neural networks (RNN) that act as an encoder and a decoder pair. The encoder maps a variable-length source sequence to a fixed-length vector, and the decoder maps the vector representation back to a variable-length target sequence. Seq2Seq sequences (vary length in input and output). Many to many architecture.
# https://machinelearningmastery.com/encoder-decoder-long-short-term-memory-networks/
#
# #### 1.2. CNN-LSTM Encoder-Decoder Model (https://ieeexplore.ieee.org/document/9587207)
# - The following model is an extension of encoder-decoder architecture where the encoder part consists of Conv1D layers, unlike the previous model. First of all, two subsequent Conv1D layers are placed at the beginning to extract features, and then it is flattened after pooling the results of Conv1D. The rest of the architecture is very similar to the previous model.
#
# #### 1.3. Vector Output Model
# - This architecture might be thought of as a much more common architecture compared to the above-mentioned models, however, it is not very suitable for our case. Nevertheless, I share an example model to give an idea. At variance with encoder-decoder architecture, neither RepeatVector nor TimeDistributed layer exists. The point is to add a Dense layer with FORECAST_RANGE*n_features node, and then reshape it accordingly at the next layer. You might also design a similar architecture with RepeatVector layer instead of Reshape layer. The time steps of each series would be flattened in this structure and must interpret each of the outputs as a specific time step for a specific series during training and prediction. That means we also might reshape our label set as 2 dimensions rather than 3 dimensions, and interpret the results in the output layer accordingly without using Reshape layer. For simplicity, I did not change the shape of the label set, but just keep it in mind this alternative way as well. I also utilized Conv1D layers at the beginning of the architecture.
# - This structure might be also called a multi-channel model. Do not overestimate the names. When dealing with multiple time series, CNNs with multiple channels are utilized traditionally. In this structure, each channel corresponds to a single time series and similarly extracts convolved features separately for each time series. Since all of the extracted features are combined before feeding into the LSTM layer, some typical features of each time series might be lost.
#
# #### 1.4. Multi-Head CNN-LSTM Model
# - This architecture is a bit different from the above-mentioned models. It is explained very clearly in the study of Canizo. The multi-head structure uses multiple one-dimensional CNN layers in order to process each time series and extract independent convolved features from each time series. These separate CNNs are called “head” and flattened, concatenated, and reshaped respectively before feeding into the LSTM layer. To summarize, multi-head structures utilize multiple CNNs rather than only one CNN like in multi-channel structure. Therefore, they might be more successful to keep significant features of each time series and make better forecasts in this sense. (https://www.sciencedirect.com/science/article/abs/pii/S0925231219309877)

# %%
# fit/train model ..........................................................
def fit_model(model, X_train, y_train, epochs, batch_size, validation, patience, verbose=1):
    early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = patience)
    history = model.fit(X_train, y_train, epochs = epochs,  validation_split = validation, 
                        batch_size = batch_size, shuffle = False, verbose= verbose,
                        callbacks=[early_stopping_callback, checkpoint_callback, rlrop_callback])
    return history

# predict ..................................................................
def prediction(model,X_test):
    prediction = model.predict(X_test)
    return prediction

# .......................................
# ---- MODELS ---------------------------
# .......................................

# model 1: GRU unit --------------------------------------------------------------
def create_model_gru(X_train, optimizer='adam'):
    
    model = Sequential()
    model.add(GRU(units = 100, input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(RepeatVector(FORECAST_RANGE))
    model.add(Dropout(0.2))
    model.add(GRU(units = 100, return_sequences = True,))
    model.add(Dropout(0.2))
    model.add(TimeDistributed(Dense(n_features)))
    
    model.compile(loss='mse', optimizer=optimizer)
    
    return model

# model 2: LSTM unit --------------------------------------------------------------
def create_model_lstm(X_train, optimizer='adam'):
    
    model = Sequential()
    model.add(LSTM(units = 100, input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(RepeatVector(FORECAST_RANGE))
    model.add(Dropout(0.2))
    model.add(LSTM(units = 100, return_sequences = True,))
    model.add(Dropout(0.2))
    model.add(TimeDistributed(Dense(n_features)))
    
    model.compile(loss='mse', optimizer=optimizer)
    
    return model

# model 3: BILSTM unit --------------------------------------------------------------
def create_model_bilstm(X_train, optimizer='adam'):
    
    model = Sequential()
    model.add(Bidirectional(LSTM(units = 100), input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(RepeatVector(FORECAST_RANGE))
    model.add(Bidirectional(LSTM(units = 100, return_sequences=True)))
    model.add(TimeDistributed(Dense(n_features)))
    
    model.compile(loss='mse', optimizer=optimizer)
    
    return model

# model 4: ENCODER-DECODER LSTM unit ------------------------------------------------
def create_model_enc_dec(X_train, optimizer='adam'):
    
    model_enc_dec = Sequential()
    model_enc_dec.add(LSTM(100, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
    model_enc_dec.add(RepeatVector(FORECAST_RANGE))
    model_enc_dec.add(LSTM(100, activation='relu', return_sequences=True))
    model_enc_dec.add(TimeDistributed(Dense(n_features)))
    
    model_enc_dec.compile(optimizer=optimizer, loss='mse')
    
    return model_enc_dec

# model 4: ENCODER-DECODER CNN unit ------------------------------------------------

#The kernel_size determines the spatial extent of the local region that is being considered for feature extraction. 
# A larger kernel size captures a broader context but may result in a higher number of parameters. 
# A smaller kernel size captures finer details but may require more layers to learn complex patterns. 
# Common values for kernel_size are 3x3, 5x5, or 7x7.
#   -  Smaller Kernel (e.g., 3x3): Captures fine-grained features, well-suited for capturing small patterns and edges.
#   -  Larger Kernel (e.g., 5x5 or 7x7): Captures more global features and spatial hierarchies.
#   -  Smaller kernels may require deeper networks to capture complex patterns.
#   -  Larger kernels may result in more parameters and computational cost.

def create_model_enc_dec_cnn(X_train, optimizer='adam',kern_size = 3):
    
    model_enc_dec_cnn = Sequential()
    model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=kern_size, activation='relu', 
                                 input_shape=(X_train.shape[1], X_train.shape[2])))
    model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=kern_size, activation='relu'))
    model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
    model_enc_dec_cnn.add(Flatten())
    model_enc_dec_cnn.add(RepeatVector(FORECAST_RANGE))
    model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
    model_enc_dec_cnn.add(TimeDistributed(Dense(100, activation='relu')))
    model_enc_dec_cnn.add(TimeDistributed(Dense(n_features)))
    
    model_enc_dec_cnn.compile(loss='mse', optimizer=optimizer)
    
    return model_enc_dec_cnn


# model 5: VECTOR OUTPUT -----------------------------------------------------------
def create_model_vector_output(X_train, optimizer='adam',kern_size = 3):
    
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2])) 
    conv = Conv1D(filters=4, kernel_size=kern_size, activation='relu')(input_layer)
    conv = Conv1D(filters=6, kernel_size=kern_size, activation='relu')(conv)

    lstm = LSTM(100, return_sequences=True, activation='relu')(conv)
    dropout = Dropout(0.2)(lstm)
    lstm = LSTM(100, activation='relu')(dropout)
    dense = Dense(FORECAST_RANGE*n_features, activation='relu')(lstm)
    output_layer = Reshape((FORECAST_RANGE,n_features))(dense)
    model_vector_output = Model([input_layer], [output_layer])
    
    model_vector_output.compile(optimizer=optimizer, loss='mse')
    
    return model_vector_output

# model 6: Multi head LSTM cnn -----------------------------------------------------------
def create_model_multi_head_cnn_lstm(X_train, optimizer='adam',kern_size = 3):
    
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))  #Look back, n_features
    head_list = []
    for i in range(0, n_features):
        conv_layer_head = Conv1D(filters=4, kernel_size=kern_size, activation='relu')(input_layer)
        conv_layer_head_2 = Conv1D(filters=6, kernel_size=kern_size, activation='relu')(conv_layer_head)
        conv_layer_flatten = Flatten()(conv_layer_head_2)
        head_list.append(conv_layer_flatten)

    concat_cnn = Concatenate(axis=1)(head_list)
    reshape = Reshape((head_list[0].shape[1], n_features))(concat_cnn)
    lstm = LSTM(100, activation='relu')(reshape)
    repeat = RepeatVector(FORECAST_RANGE)(lstm)
    lstm_2 = LSTM(100, activation='relu', return_sequences=True)(repeat)
    dropout = Dropout(0.2)(lstm_2)
    dense = Dense(n_features, activation='linear')(dropout)
    multi_head_cnn_lstm_model = Model(inputs=input_layer, outputs=dense)
    
    multi_head_cnn_lstm_model.compile(optimizer=optimizer, loss='mse')
    
    return multi_head_cnn_lstm_model

# %% [markdown]
# ### Define imputs

# %%
# Objective and predictors ...................................
objective = "timeseries_350"
cc_predictors = ['timeseries_405','timeseries_363','timeseries_975','timeseries_120','timeseries_2','timeseries_541','timeseries_775',
                 'timeseries_181','timeseries_692','timeseries_443','timeseries_763','timeseries_31','timeseries_324'] 

# df definition ..............................................
cc_predictors.append(objective)
variables_predictors = cc_predictors.copy()
subdf = smoothed[cc_predictors]

# Add temporality (weekday and month) ........................
temporality = False
if temporality:
    subdf['weekday'] = subdf['date'].dt.day_name()
    subdf['month'] = subdf['date'].dt.month_name()
    dummies_day = pd.get_dummies(subdf['weekday'], prefix='weekday_')
    dummies_month = pd.get_dummies(subdf['month'], prefix='month_')
    dummies_day = dummies_day.astype(int)
    dummies_month = dummies_month.astype(int)
    subdf = pd.concat([subdf, dummies_day, dummies_month], axis=1)
    subdf = subdf.drop('weekday', axis = 1)
    subdf = subdf.drop('month', axis = 1)
    cc_predictors = cc_predictors + dummies_day.columns.tolist()
    cc_predictors = cc_predictors + dummies_month.columns.tolist()
    cc_predictors.remove('date')

# put objective to last column ..............................
cc_predictors = [col for col in subdf.columns if col != objective]
cc_predictors.append(objective)
subdf = subdf[cc_predictors]
display(subdf) 

# train-test split ...........................................
train_size = int(len(subdf)*0.8)
train_dataset, test_dataset = subdf.iloc[5:train_size],subdf.iloc[train_size:]

# Plot train and test data ...................................
plt.figure(figsize = (10, 4))
plt.plot(train_dataset[objective])
plt.plot(test_dataset[objective])
plt.xlabel('Time (day)')
plt.ylabel('n diags Hipertension')
plt.legend(['Train set', 'Test set'], loc='upper right')

print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)

#scale ......................................................
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_dataset)
scaled_test = scaler.transform(test_dataset)

# get idx of objective variable
col_idx = subdf.columns.get_loc(objective)

# %% [markdown]
# ### DL parameters

# %%
LOOK_BACK =  30 #731 (2 anys)     # quants dies amb anterioritat mires abans de predir
FORECAST_RANGE = 8                # quants dies em de predir
n_features = len(cc_predictors)   # quantes variables (sistema molt sensible)
  
epochs = 10#0
batch_size = 128
validation = 0.1
patience = 10

X_train, y_train = split_sequence(scaled_train, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
X_test, y_test = split_sequence(scaled_test, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %% [markdown]
# ### MODEL EVALUATION

# %%
# GRU model .........................................................................................................
print('\n >>>>> model 1: GRU')
model_gru = create_model_gru(X_train)
history = fit_model(model_gru,X_train, y_train, epochs, batch_size, validation, patience)
yhat_gru = prediction(model_gru,X_test)
y_test_inverse, yhat_gru_inverse = inverse_transform(y_test, yhat_gru)
evaluate_forecast(y_test_inverse, yhat_gru_inverse)
plt_model(y_test_inverse, yhat_gru_inverse,"GRU")

# LSTM model ........................................................................................................
print('\n >>>>> model 2: LSTM')
model_lstm = create_model_lstm(X_train)
history = fit_model(model_lstm,X_train, y_train, epochs, batch_size, validation, patience)
yhat_lstm = prediction(model_lstm,X_test)
y_test_inverse, yhat_lstm_inverse = inverse_transform(y_test, yhat_lstm)
evaluate_forecast(y_test_inverse, yhat_lstm_inverse)
plt_model(y_test_inverse, yhat_lstm_inverse,"LSTM")

# Bi-directional model .............................................................................................
print('\n >>>>> model 3: Bi-directional')
model_bilstm = create_model_bilstm(X_train)
history = fit_model(model_bilstm,X_train, y_train, epochs, batch_size, validation, patience)
yhat_bilstm = prediction(model_bilstm,X_test)
y_test_inverse, yhat_bilstm_inverse = inverse_transform(y_test, yhat_bilstm)
evaluate_forecast(y_test_inverse, yhat_bilstm_inverse)
plt_model(y_test_inverse, yhat_bilstm_inverse,"Bi-directional_LSTM")

# Encoder-decoder LSTM model .......................................................................................
print('\n >>>>> model 4: Encoder-decoder LSTM')
model_enc_dec = create_model_enc_dec(X_train)
history = fit_model(model_enc_dec,X_train, y_train, epochs, batch_size, validation, patience)
yhat_endelstm = prediction(model_enc_dec,X_test)
y_test_inverse, yhat_endelstm_inverse = inverse_transform(y_test, yhat_endelstm)
evaluate_forecast(y_test_inverse, yhat_endelstm_inverse)
plt_model(y_test_inverse, yhat_endelstm_inverse,"ENCODER_DECODER_LSTM")

# CNN-LSTM Encoder-Decoder model ...................................................................................
print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
model_enc_dec_cnn = create_model_enc_dec_cnn(X_train)
history = fit_model(model_enc_dec_cnn, X_train, y_train, epochs, batch_size, validation, patience)
yhat_cnnlstmende = prediction(model_enc_dec_cnn,X_test)
y_test_inverse, yhat_cnnlstmende_inverse = inverse_transform(y_test, yhat_cnnlstmende)
evaluate_forecast(y_test_inverse, yhat_cnnlstmende_inverse)
plt_model(y_test_inverse, yhat_cnnlstmende_inverse,"Encoder_DECODER_CNN_LSTM")

# Vector-Output model .............................................................................................
print('\n >>>>> model 6: Vector-Output')
model_vector_output = create_model_vector_output(X_train)
history = fit_model(model_vector_output, X_train, y_train, epochs, batch_size, validation, patience)
yhat_veout = prediction(model_vector_output,X_test)
y_test_inverse, yhat_veout_inverse = inverse_transform(y_test, yhat_veout)
evaluate_forecast(y_test_inverse, yhat_veout_inverse)
plt_model(y_test_inverse, yhat_veout_inverse,"Encoder_DECODER_CNN_LSTM")

# Multi-Head CNN-LSTM model ......................................................................................
print('\n >>>>> model 7: Multi-Head CNN-LSTM')
multi_head_cnn_lstm_model = create_model_multi_head_cnn_lstm(X_train)
history = fit_model(multi_head_cnn_lstm_model, X_train, y_train, epochs, batch_size, validation, patience)
yhat_muhecnnlstm = prediction(multi_head_cnn_lstm_model,X_test)
y_test_inverse, yhat_muhecnnlstm_inverse = inverse_transform(y_test, yhat_muhecnnlstm)
evaluate_forecast(y_test_inverse, yhat_muhecnnlstm_inverse)
plt_model(y_test_inverse, yhat_muhecnnlstm_inverse, "Multi-Head CNN-LSTM")

# %% [markdown]
# ### Get results all together

# %%
# GRU model .........................................................................................................
print('\n >>>>> model 1: GRU')
evaluate_forecast(y_test_inverse, yhat_gru_inverse)
#plt_model(y_test_inverse, yhat_gru_inverse,"GRU")

# LSTM model ........................................................................................................
print('\n >>>>> model 2: LSTM')
evaluate_forecast(y_test_inverse, yhat_lstm_inverse)
#plt_model(y_test_inverse, yhat_lstm_inverse,"LSTM")

# Bi-directional model .............................................................................................
print('\n >>>>> model 3: Bi-directional')
evaluate_forecast(y_test_inverse, yhat_bilstm_inverse)
#plt_model(y_test_inverse, yhat_bilstm_inverse,"Bi-directional_LSTM")

# Encoder-decoder LSTM model .......................................................................................
print('\n >>>>> model 4: Encoder-decoder LSTM')
evaluate_forecast(y_test_inverse, yhat_endelstm_inverse)
#plt_model(y_test_inverse, yhat_endelstm_inverse,"ENCODER_DECODER_LSTM")

# CNN-LSTM Encoder-Decoder model ...................................................................................
print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
evaluate_forecast(y_test_inverse, yhat_cnnlstmende_inverse)
#plt_model(y_test_inverse, yhat_cnnlstmende_inverse,"Encoder_DECODER_CNN_LSTM")

# Vector-Output model .............................................................................................
print('\n >>>>> model 6: Vector-Output')
evaluate_forecast(y_test_inverse, yhat_veout_inverse)
#plt_model(y_test_inverse, yhat_veout_inverse,"Encoder_DECODER_CNN_LSTM")

# Multi-Head CNN-LSTM model ......................................................................................
print('\n >>>>> model 7: Multi-Head CNN-LSTM')
evaluate_forecast(y_test_inverse, yhat_muhecnnlstm_inverse)
#plt_model(y_test_inverse, yhat_muhecnnlstm_inverse, "Multi-Head CNN-LSTM")  

# PLOT ----------------------------------------------------------------------------------------------------------
# plot models
plt.figure(figsize=(20, 10))
plt.plot(pd.DataFrame(y_test_inverse)[[col_idx]], label='True Values', linewidth=2.5)
plt.plot(pd.DataFrame(yhat_gru_inverse)[[col_idx]], label='Pred. GRU', linestyle='--')
plt.plot(pd.DataFrame(yhat_lstm_inverse)[[col_idx]], label='Pred. LSTM', linestyle='--')
plt.plot(pd.DataFrame(yhat_bilstm_inverse)[[col_idx]], label='Pred. BiLSTM', linestyle='--')
plt.plot(pd.DataFrame(yhat_endelstm_inverse)[[col_idx]], label='Pred. Enc-Dec LSTM', linestyle='--')
plt.plot(pd.DataFrame(yhat_cnnlstmende_inverse)[[col_idx]], label='Pred. CNN-LSTM Enc-Dec', linestyle='--')
plt.plot(pd.DataFrame(yhat_veout_inverse)[[col_idx]], label='Pred. Vector Output', linestyle='--')
plt.plot(pd.DataFrame(yhat_muhecnnlstm_inverse)[[col_idx]], label='Pred. Mult-Head CNN-LSTM', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Real vs. Predicted Values MODELS')
plt.legend()
plt.show()

# %% [markdown]
# ### grid search params

# %%
def auto_grid_search(model):
    import tensorflow as tf

    # Define search space inside
    epochs_list = [10, 20, 30, 50, 100, 200, 500, 1000] 
    bt_size = [10, 20, 40, 60, 80, 100, 200, 500, 1000]
    opti = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']

    var1, var2, var3 = 'epochs', 'batch_size', 'optimizer'
    mapes = []

    # Grid search epochs
    for epo in epochs_list:
        model_ = model(X_train)
        history = fit_model(model_, X_train, y_train, epo, 128, validation, patience, verbose=0)
        yhat_ = prediction(model_, X_test)
        y_test_inverse, yhat_inverse = inverse_transform(y_test, yhat_)
        mape = tf.keras.losses.MeanAbsolutePercentageError()(y_test_inverse, yhat_inverse)
        mapes.append(mape)
        print(f'mape: {mape:.4f}  // model: {epo} {var1}')
    best_epochs = epochs_list[mapes.index(min(mapes))]
    print(f"BEST: {min(mapes):.4f} USING {best_epochs} {var1}")

    # Grid search batch size
    mapes = []
    for bt in bt_size:
        model_ = model(X_train)
        history = fit_model(model_, X_train, y_train, best_epochs, bt, validation, patience, verbose=0)
        yhat_ = prediction(model_, X_test)
        y_test_inverse, yhat_inverse = inverse_transform(y_test, yhat_)
        mape = tf.keras.losses.MeanAbsolutePercentageError()(y_test_inverse, yhat_inverse)
        mapes.append(mape)
        print(f'mape: {mape:.4f}  // model: {bt} {var2}')
    best_bt = bt_size[mapes.index(min(mapes))]
    print(f"BEST: {min(mapes):.4f} USING {best_bt} {var2} (and {best_epochs} epochs)")

    # Grid search optimizer
    mapes = []
    for opt in opti:
        model_ = model(X_train, optimizer=opt)
        history = fit_model(model_, X_train, y_train, best_epochs, best_bt, validation, patience, verbose=0)
        yhat_ = prediction(model_, X_test)
        y_test_inverse, yhat_inverse = inverse_transform(y_test, yhat_)
        mape = tf.keras.losses.MeanAbsolutePercentageError()(y_test_inverse, yhat_inverse)
        mapes.append(mape)
        print(f'mape: {mape:.4f}  // model: {opt} {var3}')
    best_opt = opti[mapes.index(min(mapes))]
    print(f"BEST: {min(mapes):.4f} USING {best_opt} {var3} (and {best_epochs} epochs and {best_bt} batch_size)")

# %%
print('\n>>> GRID SEARCH PARAMETERS ... GRU model')
auto_grid_search(create_model_gru)
print('\n>>> GRID SEARCH PARAMETERS ... LSTM model')
auto_grid_search(create_model_lstm)
print('\n>>> GRID SEARCH PARAMETERS ... Bi-LSTM model')
auto_grid_search(create_model_bilstm)
print('\n>>> GRID SEARCH PARAMETERS ...encoder-decoder model')
auto_grid_search(create_model_enc_dec)
print('\n>>> GRID SEARCH PARAMETERS ... encoder-decoder cnn model')
auto_grid_search(create_model_enc_dec_cnn)
print('\n>>> GRID SEARCH PARAMETERS ... vector output model')
auto_grid_search(create_model_vector_output)
print('\n>>> GRID SEARCH PARAMETERS ... multi head cnn lstm model')
auto_grid_search(create_model_multi_head_cnn_lstm)

# %% [markdown]
# # RUN ALL WITH CORRECT PARAMS AND DIFFERENT LOOK BACK TIME

# %%
FORECAST_RANGE = 7                 # quants dies em de predir
n_features = len(cc_predictors)   # quantes variables (sistema molt sensible)

validation = 0.1
patience = 10
LOOK_BACKS = [7,14,30,60,90,180,365,730]

for LOOK_BACK in LOOK_BACKS:
    
    print("\n \n \n >>>> LOOK BACK PARAMETER: %s" % (LOOK_BACK))
    
    X_train, y_train = split_sequence(scaled_train, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
    X_test, y_test = split_sequence(scaled_test, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
    
    # GRU model .........................................................................................................
    print('\n >>>>> model 1: GRU')
    model_gru = create_model_gru(X_train, optimizer='Nadam')
    history = fit_model(model_gru,X_train, y_train,100, 80, validation, patience)
    yhat_gru = prediction(model_gru,X_test)
    y_test_inverse, yhat_gru_inverse = inverse_transform(y_test, yhat_gru)

    # LSTM model ........................................................................................................
    print('\n >>>>> model 2: LSTM')
    model_lstm = create_model_lstm(X_train, optimizer='Nadam')
    history = fit_model(model_lstm,X_train, y_train, 30, 80, validation, patience)
    yhat_lstm = prediction(model_lstm,X_test)
    y_test_inverse, yhat_lstm_inverse = inverse_transform(y_test, yhat_lstm)

    # Bi-directional model .............................................................................................
    print('\n >>>>> model 3: Bi-directional')
    model_bilstm = create_model_bilstm(X_train, optimizer='adam')
    history = fit_model(model_bilstm,X_train, y_train, 100, 500, validation, patience)
    yhat_bilstm = prediction(model_bilstm,X_test)
    y_test_inverse, yhat_bilstm_inverse = inverse_transform(y_test, yhat_bilstm)

    # Encoder-decoder LSTM model .......................................................................................
    print('\n >>>>> model 4: Encoder-decoder LSTM')
    model_enc_dec = create_model_enc_dec(X_train, optimizer='Adamax')
    history = fit_model(model_enc_dec,X_train, y_train, 200, 10, validation, patience)
    yhat_endelstm = prediction(model_enc_dec,X_test)
    y_test_inverse, yhat_endelstm_inverse = inverse_transform(y_test, yhat_endelstm)

    # CNN-LSTM Encoder-Decoder model ...................................................................................
    print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
    model_enc_dec_cnn = create_model_enc_dec_cnn(X_train, optimizer='Nadam',kern_size=3)
    history = fit_model(model_enc_dec_cnn, X_train, y_train, 20, 500, validation, patience)
    yhat_cnnlstmende = prediction(model_enc_dec_cnn,X_test)
    y_test_inverse, yhat_cnnlstmende_inverse = inverse_transform(y_test, yhat_cnnlstmende)

    # Vector-Output model .............................................................................................
    print('\n >>>>> model 6: Vector-Output')
    model_vector_output = create_model_vector_output(X_train, optimizer='Adam',kern_size=3)
    history = fit_model(model_vector_output, X_train, y_train, 50, 10, validation, patience)
    yhat_veout = prediction(model_vector_output,X_test)
    y_test_inverse, yhat_veout_inverse = inverse_transform(y_test, yhat_veout)

    # Multi-Head CNN-LSTM model ......................................................................................
    print('\n >>>>> model 7: Multi-Head CNN-LSTM')
    multi_head_cnn_lstm_model = create_model_multi_head_cnn_lstm(X_train, optimizer='Nadam',kern_size=3)
    history = fit_model(multi_head_cnn_lstm_model, X_train, y_train, 500, 40, validation, patience)
    yhat_muhecnnlstm = prediction(multi_head_cnn_lstm_model,X_test)
    y_test_inverse, yhat_muhecnnlstm_inverse = inverse_transform(y_test, yhat_muhecnnlstm)

        # GRU model .........................................................................................................
    print('\n >>>>> model 1: GRU')
    evaluate_forecast(y_test_inverse, yhat_gru_inverse)
    print('\n >>>>> model 2: LSTM')
    evaluate_forecast(y_test_inverse, yhat_lstm_inverse)
    print('\n >>>>> model 3: Bi-directional')
    evaluate_forecast(y_test_inverse, yhat_bilstm_inverse)
    print('\n >>>>> model 4: Encoder-decoder LSTM')
    evaluate_forecast(y_test_inverse, yhat_endelstm_inverse)
    print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
    evaluate_forecast(y_test_inverse, yhat_cnnlstmende_inverse)
    print('\n >>>>> model 6: Vector-Output')
    evaluate_forecast(y_test_inverse, yhat_veout_inverse)
    print('\n >>>>> model 7: Multi-Head CNN-LSTM')
    evaluate_forecast(y_test_inverse, yhat_muhecnnlstm_inverse)

    # PLOT ----------------------------------------------------------------------------------------------------------
    # plot models
    plt.figure(figsize=(20, 10))
    plt.plot(pd.DataFrame(y_test_inverse)[[col_idx]], label='True Values', linewidth=2.5)
    plt.plot(pd.DataFrame(yhat_gru_inverse)[[col_idx]], label='Pred. GRU', linestyle='--')
    plt.plot(pd.DataFrame(yhat_lstm_inverse)[[col_idx]], label='Pred. LSTM', linestyle='--')
    plt.plot(pd.DataFrame(yhat_bilstm_inverse)[[col_idx]], label='Pred. BiLSTM', linestyle='--')
    plt.plot(pd.DataFrame(yhat_endelstm_inverse)[[col_idx]], label='Pred. Enc-Dec LSTM', linestyle='--')
    plt.plot(pd.DataFrame(yhat_cnnlstmende_inverse)[[col_idx]], label='Pred. CNN-LSTM Enc-Dec', linestyle='--')
    plt.plot(pd.DataFrame(yhat_veout_inverse)[[col_idx]], label='Pred. Vector Output', linestyle='--')
    plt.plot(pd.DataFrame(yhat_muhecnnlstm_inverse)[[col_idx]], label='Pred. Mult-Head CNN-LSTM', linestyle='--')
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.title('Real vs. Predicted Values MODELS')
    plt.legend()
    plt.show()

# %%
FORECAST_RANGE = [1,7,14,21,28]                 # quants dies em de predir
n_features = len(cc_predictors)   # quantes variables (sistema molt sensible)

validation = 0.1
patience = 10
LOOK_BACKS = [7,14,30,60,90,180,365,730]

for LOOK_BACK in LOOK_BACKS:
    for FORECAST in FORECAST_RANGE: 
    
        print("\n \n \n >>>> LOOK BACK PARAMETER: %s" % (LOOK_BACK))

        X_train, y_train = split_sequence(scaled_train, look_back=LOOK_BACK, forecast_horizon=FORECAST)
        X_test, y_test = split_sequence(scaled_test, look_back=LOOK_BACK, forecast_horizon=FORECAST)

        # GRU model .........................................................................................................
        print('\n >>>>> model 1: GRU')
        model_gru = create_model_gru(X_train, optimizer='Nadam')
        history = fit_model(model_gru,X_train, y_train,100, 80, validation, patience)
        yhat_gru = prediction(model_gru,X_test)
        y_test_inverse, yhat_gru_inverse = inverse_transform(y_test, yhat_gru)

        # LSTM model ........................................................................................................
        print('\n >>>>> model 2: LSTM')
        model_lstm = create_model_lstm(X_train, optimizer='Nadam')
        history = fit_model(model_lstm,X_train, y_train, 30, 80, validation, patience)
        yhat_lstm = prediction(model_lstm,X_test)
        y_test_inverse, yhat_lstm_inverse = inverse_transform(y_test, yhat_lstm)

        # Bi-directional model .............................................................................................
        print('\n >>>>> model 3: Bi-directional')
        model_bilstm = create_model_bilstm(X_train, optimizer='adam')
        history = fit_model(model_bilstm,X_train, y_train, 100, 500, validation, patience)
        yhat_bilstm = prediction(model_bilstm,X_test)
        y_test_inverse, yhat_bilstm_inverse = inverse_transform(y_test, yhat_bilstm)

        # Encoder-decoder LSTM model .......................................................................................
        print('\n >>>>> model 4: Encoder-decoder LSTM')
        model_enc_dec = create_model_enc_dec(X_train, optimizer='Adamax')
        history = fit_model(model_enc_dec,X_train, y_train, 200, 10, validation, patience)
        yhat_endelstm = prediction(model_enc_dec,X_test)
        y_test_inverse, yhat_endelstm_inverse = inverse_transform(y_test, yhat_endelstm)

        # CNN-LSTM Encoder-Decoder model ...................................................................................
        print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
        model_enc_dec_cnn = create_model_enc_dec_cnn(X_train, optimizer='Nadam',kern_size=3)
        history = fit_model(model_enc_dec_cnn, X_train, y_train, 20, 500, validation, patience)
        yhat_cnnlstmende = prediction(model_enc_dec_cnn,X_test)
        y_test_inverse, yhat_cnnlstmende_inverse = inverse_transform(y_test, yhat_cnnlstmende)

        # Vector-Output model .............................................................................................
        print('\n >>>>> model 6: Vector-Output')
        model_vector_output = create_model_vector_output(X_train, optimizer='Adam',kern_size=3)
        history = fit_model(model_vector_output, X_train, y_train, 50, 10, validation, patience)
        yhat_veout = prediction(model_vector_output,X_test)
        y_test_inverse, yhat_veout_inverse = inverse_transform(y_test, yhat_veout)

        # Multi-Head CNN-LSTM model ......................................................................................
        print('\n >>>>> model 7: Multi-Head CNN-LSTM')
        multi_head_cnn_lstm_model = create_model_multi_head_cnn_lstm(X_train, optimizer='Nadam',kern_size=3)
        history = fit_model(multi_head_cnn_lstm_model, X_train, y_train, 500, 40, validation, patience)
        yhat_muhecnnlstm = prediction(multi_head_cnn_lstm_model,X_test)
        y_test_inverse, yhat_muhecnnlstm_inverse = inverse_transform(y_test, yhat_muhecnnlstm)

            # GRU model .........................................................................................................
        print('\n >>>>> model 1: GRU')
        evaluate_forecast(y_test_inverse, yhat_gru_inverse)
        print('\n >>>>> model 2: LSTM')
        evaluate_forecast(y_test_inverse, yhat_lstm_inverse)
        print('\n >>>>> model 3: Bi-directional')
        evaluate_forecast(y_test_inverse, yhat_bilstm_inverse)
        print('\n >>>>> model 4: Encoder-decoder LSTM')
        evaluate_forecast(y_test_inverse, yhat_endelstm_inverse)
        print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
        evaluate_forecast(y_test_inverse, yhat_cnnlstmende_inverse)
        print('\n >>>>> model 6: Vector-Output')
        evaluate_forecast(y_test_inverse, yhat_veout_inverse)
        print('\n >>>>> model 7: Multi-Head CNN-LSTM')
        evaluate_forecast(y_test_inverse, yhat_muhecnnlstm_inverse)

        # PLOT ----------------------------------------------------------------------------------------------------------
        # plot models
        plt.figure(figsize=(20, 10))
        plt.plot(pd.DataFrame(y_test_inverse)[[col_idx]], label='True Values', linewidth=2.5)
        plt.plot(pd.DataFrame(yhat_gru_inverse)[[col_idx]], label='Pred. GRU', linestyle='--')
        plt.plot(pd.DataFrame(yhat_lstm_inverse)[[col_idx]], label='Pred. LSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_bilstm_inverse)[[col_idx]], label='Pred. BiLSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_endelstm_inverse)[[col_idx]], label='Pred. Enc-Dec LSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_cnnlstmende_inverse)[[col_idx]], label='Pred. CNN-LSTM Enc-Dec', linestyle='--')
        plt.plot(pd.DataFrame(yhat_veout_inverse)[[col_idx]], label='Pred. Vector Output', linestyle='--')
        plt.plot(pd.DataFrame(yhat_muhecnnlstm_inverse)[[col_idx]], label='Pred. Mult-Head CNN-LSTM', linestyle='--')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Real vs. Predicted Values MODELS')
        plt.legend()
        plt.show()

# %% [markdown]
# ## Temporality data

# %%
# Objective and predictors ...................................
objective = "timeseries_350"
cc_predictors = ['timeseries_405','timeseries_363','timeseries_975','timeseries_120','timeseries_2','timeseries_541','timeseries_775',
                 'timeseries_181','timeseries_692','timeseries_443','timeseries_763','timeseries_31','timeseries_324'] 

# df definition ..............................................
cc_predictors.append(objective)
variables_predictors = cc_predictors.copy()
subdf = smoothed[cc_predictors]

# Add temporality (weekday and month) ........................
temporality = False
if temporality:
    subdf['weekday'] = subdf['date'].dt.day_name()
    subdf['month'] = subdf['date'].dt.month_name()
    dummies_day = pd.get_dummies(subdf['weekday'], prefix='weekday_')
    dummies_month = pd.get_dummies(subdf['month'], prefix='month_')
    dummies_day = dummies_day.astype(int)
    dummies_month = dummies_month.astype(int)
    subdf = pd.concat([subdf, dummies_day, dummies_month], axis=1)
    subdf = subdf.drop('weekday', axis = 1)
    subdf = subdf.drop('month', axis = 1)
    cc_predictors = cc_predictors + dummies_day.columns.tolist()
    cc_predictors = cc_predictors + dummies_month.columns.tolist()
    cc_predictors.remove('date')


# put objective to last column ..............................
cc_predictors = [col for col in subdf.columns if col != objective]
cc_predictors.append(objective)
subdf = subdf[cc_predictors]
display(subdf) 

# train-test split ...........................................
train_size = int(len(subdf)*0.8)
train_dataset, test_dataset = subdf.iloc[5:train_size],subdf.iloc[train_size:]

#scale ......................................................
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_dataset)
scaled_test = scaler.transform(test_dataset)

# get idx of objective variable
col_idx = int(subdf.columns.get_loc(objective))-1

FORECAST = [1,7,14,21,28]                 # quants dies em de predir
n_features = len(cc_predictors)   # quantes variables (sistema molt sensible)

validation = 0.1
patience = 10
LOOK_BACKS = [7,14,30,60,90,180,365,730]

#results_df
columns = ['Algorithm', 'look_back', 'forecast_range', 'mae', 'mse', 'mape']  
result = pd.DataFrame(columns=columns)

for LOOK_BACK in LOOK_BACKS:
    for FORECAST_RANGE in FORECAST: 
    
        LOOK_BACK = int(LOOK_BACK)
        FORECAST_RANGE = int(FORECAST_RANGE)
        print("\n \n \n >>>> LOOK BACK PARAMETER: %s" % (LOOK_BACK))
        print(">>>> FORECAST RANGE PARAMETER: %s" % (FORECAST_RANGE))

        X_train, y_train = split_sequence(scaled_train, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
        X_test, y_test = split_sequence(scaled_test, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

        # GRU model .........................................................................................................
        print('\n >>>>> model 1: GRU')
        model_gru = create_model_gru(X_train, optimizer='Nadam')
        history = fit_model(model_gru,X_train, y_train,100, 80, validation, patience)
        yhat_gru = prediction(model_gru,X_test)
        y_test_inverse, yhat_gru_inverse = inverse_transform(y_test, yhat_gru)

        # LSTM model ........................................................................................................
        print('\n >>>>> model 2: LSTM')
        model_lstm = create_model_lstm(X_train, optimizer='Nadam')
        history = fit_model(model_lstm,X_train, y_train, 30, 80, validation, patience)
        yhat_lstm = prediction(model_lstm,X_test)
        y_test_inverse, yhat_lstm_inverse = inverse_transform(y_test, yhat_lstm)

        # Bi-directional model .............................................................................................
        print('\n >>>>> model 3: Bi-directional')
        model_bilstm = create_model_bilstm(X_train, optimizer='adam')
        history = fit_model(model_bilstm,X_train, y_train, 100, 500, validation, patience)
        yhat_bilstm = prediction(model_bilstm,X_test)
        y_test_inverse, yhat_bilstm_inverse = inverse_transform(y_test, yhat_bilstm)

        # Encoder-decoder LSTM model .......................................................................................
        print('\n >>>>> model 4: Encoder-decoder LSTM')
        model_enc_dec = create_model_enc_dec(X_train, optimizer='Adamax')
        history = fit_model(model_enc_dec,X_train, y_train, 200, 10, validation, patience)
        yhat_endelstm = prediction(model_enc_dec,X_test)
        y_test_inverse, yhat_endelstm_inverse = inverse_transform(y_test, yhat_endelstm)

        # CNN-LSTM Encoder-Decoder model ...................................................................................
        print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
        model_enc_dec_cnn = create_model_enc_dec_cnn(X_train, optimizer='Nadam',kern_size=3)
        history = fit_model(model_enc_dec_cnn, X_train, y_train, 20, 500, validation, patience)
        yhat_cnnlstmende = prediction(model_enc_dec_cnn,X_test)
        y_test_inverse, yhat_cnnlstmende_inverse = inverse_transform(y_test, yhat_cnnlstmende)

        # Vector-Output model .............................................................................................
        print('\n >>>>> model 6: Vector-Output')
        model_vector_output = create_model_vector_output(X_train, optimizer='Adam',kern_size=3)
        history = fit_model(model_vector_output, X_train, y_train, 50, 10, validation, patience)
        yhat_veout = prediction(model_vector_output,X_test)
        y_test_inverse, yhat_veout_inverse = inverse_transform(y_test, yhat_veout)

        # Multi-Head CNN-LSTM model ......................................................................................
        print('\n >>>>> model 7: Multi-Head CNN-LSTM')
        multi_head_cnn_lstm_model = create_model_multi_head_cnn_lstm(X_train, optimizer='Nadam',kern_size=3)
        history = fit_model(multi_head_cnn_lstm_model, X_train, y_train, 500, 40, validation, patience)
        yhat_muhecnnlstm = prediction(multi_head_cnn_lstm_model,X_test)
        y_test_inverse, yhat_muhecnnlstm_inverse = inverse_transform(y_test, yhat_muhecnnlstm)

            # GRU model .........................................................................................................
        print('\n >>>>> model 1: GRU')
        evaluate_forecast(y_test_inverse, yhat_gru_inverse)
        res = get_results(y_test_inverse, yhat_gru_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'GRU', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 2: LSTM')
        evaluate_forecast(y_test_inverse, yhat_lstm_inverse)
        res = get_results(y_test_inverse, yhat_lstm_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'LSTM', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 3: Bi-directional')
        evaluate_forecast(y_test_inverse, yhat_bilstm_inverse)
        res = get_results(y_test_inverse, yhat_bilstm_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'Bi-directional', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 4: Encoder-decoder LSTM')
        evaluate_forecast(y_test_inverse, yhat_endelstm_inverse)
        res = get_results(y_test_inverse, yhat_endelstm_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'Encoder-decoder LSTM', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 5: CNN-LSTM Encoder-Decoder')
        evaluate_forecast(y_test_inverse, yhat_cnnlstmende_inverse)
        res = get_results(y_test_inverse, yhat_cnnlstmende_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'CNN-LSTM Encoder-Decoder', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 6: Vector-Output')
        evaluate_forecast(y_test_inverse, yhat_veout_inverse)
        res = get_results(y_test_inverse, yhat_veout_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'Vector-Output', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)
        print('\n >>>>> model 7: Multi-Head CNN-LSTM')
        evaluate_forecast(y_test_inverse, yhat_muhecnnlstm_inverse)
        res = get_results(y_test_inverse, yhat_muhecnnlstm_inverse)
        new_row = pd.DataFrame([{'Algorithm': 'Multi-Head CNN-LSTM', 'look_back': LOOK_BACK, 'forecast_range': FORECAST_RANGE, 
                   'mae': res[0], 'mse': res[1], 'mape':res[2]}])
        result = pd.concat([result, new_row], ignore_index=True)

        # PLOT ----------------------------------------------------------------------------------------------------------
        # plot models
        plt.figure(figsize=(20, 10))
        plt.plot(pd.DataFrame(y_test_inverse)[[col_idx]], label='True Values', linewidth=2.5)
        plt.plot(pd.DataFrame(yhat_gru_inverse)[[col_idx]], label='Pred. GRU', linestyle='--')
        plt.plot(pd.DataFrame(yhat_lstm_inverse)[[col_idx]], label='Pred. LSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_bilstm_inverse)[[col_idx]], label='Pred. BiLSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_endelstm_inverse)[[col_idx]], label='Pred. Enc-Dec LSTM', linestyle='--')
        plt.plot(pd.DataFrame(yhat_cnnlstmende_inverse)[[col_idx]], label='Pred. CNN-LSTM Enc-Dec', linestyle='--')
        plt.plot(pd.DataFrame(yhat_veout_inverse)[[col_idx]], label='Pred. Vector Output', linestyle='--')
        plt.plot(pd.DataFrame(yhat_muhecnnlstm_inverse)[[col_idx]], label='Pred. Mult-Head CNN-LSTM', linestyle='--')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Real vs. Predicted Values MODELS (FORECAST RANGE: %s // LOOK BACK: %s)'%(FORECAST_RANGE,LOOK_BACK))
        plt.legend()
        plt.show()
        
        display(result)

# %%
# Convert the "mae," "mse," and "mape" columns to numeric if they are not already
result_df['mae'] = pd.to_numeric(result_df['mae'])
result_df['mse'] = pd.to_numeric(result_df['mse'])
result_df['mape'] = pd.to_numeric(result_df['mape'])
result_df

#result_df.to_excel("result_forecast_look.xlsx", index=False)

# %%
# Create line plots
plt.figure(figsize=(10, 6))

# Using Seaborn for color-coding by algorithm
sns.lineplot(data=result_df, x='look_back', y='forecast_range', hue='Algorithm', style='Algorithm', markers=True)

# Set labels and title
plt.xlabel('Look Back')
plt.ylabel('Forecast Range')
plt.title('Line Plots of Look Back vs. Forecast Range by Algorithm')

# Show the legend
plt.legend(title='Algorithm')

# Display the plot
plt.show()

# %% [markdown]
# # ARIMA MODEL

# %%
FORECAST_RANGE = 7                 # quants dies em de predir
n_features = len(cc_predictors)   # quantes variables (sistema molt sensible)

validation = 0.1
patience = 10
LOOK_BACKS = [7,14,30,60,90,180,365,730]
LOOK_BACK = 7
#for LOOK_BACK in LOOK_BACKS:
    
    
# train-test split ...........................................
train_size = int(len(subdf)*0.8)
train_dataset, test_dataset = subdf.iloc[5:train_size],subdf.iloc[train_size:]
tr_ds = train_dataset[[objective]]
ts_ds = test_dataset[[objective]]



    
print("\n \n \n >>>> LOOK BACK PARAMETER: %s" % (LOOK_BACK))
    
X_train, y_train = split_sequence(tr_ds, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)
X_test, y_test = split_sequence(ts_ds, look_back=LOOK_BACK, forecast_horizon=FORECAST_RANGE)

   
print('\n >>>>> model 7: ARIMA')
for i in range(len(X_train)):
    arima_model = ARIMA(X_train[i], order=(2,1,3))
    model = arima_model.fit()
    yhat_arima = model.predict(start=0, end=FORECAST_RANGE)
    evaluate_forecast(y_test, yhat_arima)

    # PLOT ----------------------------------------------------------------------------------------------------------
    # plot models
plt.figure(figsize=(20, 10))
plt.plot(pd.DataFrame(y_test), label='True Values', linewidth=2.5)
plt.plot(pd.DataFrame(yhat_arima), label='Pred. GRU', linestyle='--')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Real vs. Predicted Values MODELS')
plt.legend()
plt.show()
# Out:
# mae: tf.Tensor(86.08014291016593, shape=(), dtype=float64)
# mse: tf.Tensor(8381.30922365042, shape=(), dtype=float64)
# mape: tf.Tensor(76.92132133493939, shape=(), dtype=float64)
# mae: tf.Tensor(83.62846368233456, shape=(), dtype=float64)
# mse: tf.Tensor(7992.263635805765, shape=(), dtype=float64)
# mape: tf.Tensor(74.8479748370286, shape=(), dtype=float64)
# mae: tf.Tensor(82.00350422941699, shape=(), dtype=float64)
# mse: tf.Tensor(7775.590951652088, shape=(), dtype=float64)
# mape: tf.Tensor(73.4737722281768, shape=(), dtype=float64)
# mae: tf.Tensor(82.63602174619058, shape=(), dtype=float64)
# mse: tf.Tensor(7852.906556171393, shape=(), dtype=float64)
# mape: tf.Tensor(74.00868232709284, shape=(), dtype=float64)
# mae: tf.Tensor(83.28299589439526, shape=(), dtype=float64)
# mse: tf.Tensor(7951.13140362937, shape=(), dtype=float64)
# mape: tf.Tensor(74.55581817145267, shape=(), dtype=float64)
# mae: tf.Tensor(83.1233366074593, shape=(), dtype=float64)
# mse: tf.Tensor(7919.507360100786, shape=(), dtype=float64)
# mape: tf.Tensor(74.42079682784876, shape=(), dtype=float64)
# mae: tf.Tensor(81.21242827548238, shape=(), dtype=float64)
# mse: tf.Tensor(7615.387233564109, shape=(), dtype=float64)
# mape: tf.Tensor(72.8047717569681, shape=(), dtype=float64)
# mae: tf.Tensor(80.80567138773381, shape=(), dtype=float64)
# mse: tf.Tensor(7540.168817999311, shape=(), dtype=float64)
# mape: tf.Tensor(72.46078386526473, shape=(), dtype=float64)
# mae: tf.Tensor(78.509422728378, shape=(), dtype=float64)
# mse: tf.Tensor(7211.530652834139, shape=(), dtype=float64)
# mape: tf.Tensor(70.51888255037738, shape=(), dtype=float64)
# mae: tf.Tensor(77.63994896693693, shape=(), dtype=float64)
# mse: tf.Tensor(7144.65611689866, shape=(), dtype=float64)
# mape: tf.Tensor(69.78321307823941, shape=(), dtype=float64)
# mae: tf.Tensor(76.23918101304353, shape=(), dtype=float64)
# mse: tf.Tensor(6951.032744042644, shape=(), dtype=float64)
# mape: tf.Tensor(68.59885722034775, shape=(), dtype=float64)
# mae: tf.Tensor(76.68699686248007, shape=(), dtype=float64)
# mse: tf.Tensor(6988.499175287898, shape=(), dtype=float64)
# mape: tf.Tensor(68.9776857070596, shape=(), dtype=float64)
# mae: tf.Tensor(76.65937439982065, shape=(), dtype=float64)
# mse: tf.Tensor(6971.924962544266, shape=(), dtype=float64)
# mape: tf.Tensor(68.95432582556754, shape=(), dtype=float64)
# mae: tf.Tensor(75.48533602438378, shape=(), dtype=float64)
# mse: tf.Tensor(6792.739112213835, shape=(), dtype=float64)
# mape: tf.Tensor(67.96146006788923, shape=(), dtype=float64)
# mae: tf.Tensor(75.20507140248442, shape=(), dtype=float64)
# mse: tf.Tensor(6754.087218110618, shape=(), dtype=float64)
# mape: tf.Tensor(67.72444469258781, shape=(), dtype=float64)
# mae: tf.Tensor(73.1809825548878, shape=(), dtype=float64)
# mse: tf.Tensor(6493.579675319396, shape=(), dtype=float64)
# mape: tf.Tensor(66.0127046427539, shape=(), dtype=float64)
# mae: tf.Tensor(71.91353943287761, shape=(), dtype=float64)
# mse: tf.Tensor(6355.98709636872, shape=(), dtype=float64)
# mape: tf.Tensor(64.93676555655381, shape=(), dtype=float64)
# mae: tf.Tensor(72.34477137096383, shape=(), dtype=float64)
# mse: tf.Tensor(6387.53775813553, shape=(), dtype=float64)
# mape: tf.Tensor(65.30547806193108, shape=(), dtype=float64)
# mae: tf.Tensor(73.56174511659833, shape=(), dtype=float64)
# mse: tf.Tensor(6549.225116048877, shape=(), dtype=float64)
# mape: tf.Tensor(66.33463524034745, shape=(), dtype=float64)
# mae: tf.Tensor(73.75074416219451, shape=(), dtype=float64)
# mse: tf.Tensor(6567.594367907898, shape=(), dtype=float64)
# mape: tf.Tensor(66.49454305772399, shape=(), dtype=float64)
# mae: tf.Tensor(71.9560700734391, shape=(), dtype=float64)
# mse: tf.Tensor(6323.47194289689, shape=(), dtype=float64)
# mape: tf.Tensor(64.97680480582908, shape=(), dtype=float64)
# mae: tf.Tensor(70.89107317454118, shape=(), dtype=float64)
# mse: tf.Tensor(6174.0839652117675, shape=(), dtype=float64)
# mape: tf.Tensor(64.07589972709316, shape=(), dtype=float64)
# mae: tf.Tensor(68.93964770523145, shape=(), dtype=float64)
# mse: tf.Tensor(5944.0912470658595, shape=(), dtype=float64)
# mape: tf.Tensor(62.425854526356254, shape=(), dtype=float64)
# mae: tf.Tensor(66.79689273564995, shape=(), dtype=float64)
# mse: tf.Tensor(5727.894313076389, shape=(), dtype=float64)
# mape: tf.Tensor(60.59487042168341, shape=(), dtype=float64)
# mae: tf.Tensor(65.85401757662989, shape=(), dtype=float64)
# mse: tf.Tensor(5618.399703975181, shape=(), dtype=float64)
# mape: tf.Tensor(59.794140212220476, shape=(), dtype=float64)
# mae: tf.Tensor(66.00196661547427, shape=(), dtype=float64)
# mse: tf.Tensor(5623.734345490836, shape=(), dtype=float64)
# mape: tf.Tensor(59.9142901327056, shape=(), dtype=float64)
# mae: tf.Tensor(65.75340569667169, shape=(), dtype=float64)
# mse: tf.Tensor(5578.253383814839, shape=(), dtype=float64)
# mape: tf.Tensor(59.70895512971799, shape=(), dtype=float64)
# mae: tf.Tensor(64.33273070146538, shape=(), dtype=float64)
# mse: tf.Tensor(5397.2700447414445, shape=(), dtype=float64)
# mape: tf.Tensor(58.51429705861004, shape=(), dtype=float64)
# mae: tf.Tensor(63.4553392455058, shape=(), dtype=float64)
# mse: tf.Tensor(5295.973903696147, shape=(), dtype=float64)
# mape: tf.Tensor(57.768547928346784, shape=(), dtype=float64)
# mae: tf.Tensor(62.022514960206024, shape=(), dtype=float64)
# mse: tf.Tensor(5147.8846628236615, shape=(), dtype=float64)
# mape: tf.Tensor(56.53922778477037, shape=(), dtype=float64)
# mae: tf.Tensor(60.78897170900231, shape=(), dtype=float64)
# mse: tf.Tensor(5033.337313330072, shape=(), dtype=float64)
# mape: tf.Tensor(55.46311672590328, shape=(), dtype=float64)
# mae: tf.Tensor(59.845213570464345, shape=(), dtype=float64)
# mse: tf.Tensor(4933.266705099227, shape=(), dtype=float64)
# mape: tf.Tensor(54.655909927227796, shape=(), dtype=float64)
# mae: tf.Tensor(60.8442184377433, shape=(), dtype=float64)
# mse: tf.Tensor(5033.576711668913, shape=(), dtype=float64)
# mape: tf.Tensor(55.51068327103219, shape=(), dtype=float64)
# mae: tf.Tensor(60.11261175983937, shape=(), dtype=float64)
# mse: tf.Tensor(4941.641953277734, shape=(), dtype=float64)
# mape: tf.Tensor(54.902333340611904, shape=(), dtype=float64)
# mae: tf.Tensor(58.9754879833872, shape=(), dtype=float64)
# mse: tf.Tensor(4813.758409937746, shape=(), dtype=float64)
# mape: tf.Tensor(53.93669685725731, shape=(), dtype=float64)
# mae: tf.Tensor(58.257541245577045, shape=(), dtype=float64)
# mse: tf.Tensor(4736.341509254552, shape=(), dtype=float64)
# mape: tf.Tensor(53.322847439361894, shape=(), dtype=float64)
# mae: tf.Tensor(56.41695421238485, shape=(), dtype=float64)
# mse: tf.Tensor(4554.948594208192, shape=(), dtype=float64)
# mape: tf.Tensor(51.72538517227268, shape=(), dtype=float64)
# mae: tf.Tensor(55.42880445015293, shape=(), dtype=float64)
# mse: tf.Tensor(4470.148527276656, shape=(), dtype=float64)
# mape: tf.Tensor(50.83765008863933, shape=(), dtype=float64)
# mae: tf.Tensor(55.377773774655395, shape=(), dtype=float64)
# mse: tf.Tensor(4458.869921945527, shape=(), dtype=float64)
# mape: tf.Tensor(50.81133540619757, shape=(), dtype=float64)
# mae: tf.Tensor(56.09008736762568, shape=(), dtype=float64)
# mse: tf.Tensor(4528.037510744478, shape=(), dtype=float64)
# mape: tf.Tensor(51.429696066791486, shape=(), dtype=float64)
# mae: tf.Tensor(56.19965319458035, shape=(), dtype=float64)
# mse: tf.Tensor(4536.258819555702, shape=(), dtype=float64)
# mape: tf.Tensor(51.53083294810239, shape=(), dtype=float64)
# mae: tf.Tensor(54.817302031564914, shape=(), dtype=float64)
# mse: tf.Tensor(4395.244742284952, shape=(), dtype=float64)
# mape: tf.Tensor(50.34020434021126, shape=(), dtype=float64)
# mae: tf.Tensor(54.08767259029971, shape=(), dtype=float64)
# mse: tf.Tensor(4320.192857296562, shape=(), dtype=float64)
# mape: tf.Tensor(49.70936790284134, shape=(), dtype=float64)
# mae: tf.Tensor(52.54834506888055, shape=(), dtype=float64)
# mse: tf.Tensor(4178.628027578041, shape=(), dtype=float64)
# mape: tf.Tensor(48.35447640280581, shape=(), dtype=float64)
# mae: tf.Tensor(51.323827620266364, shape=(), dtype=float64)
# mse: tf.Tensor(4090.0717508006483, shape=(), dtype=float64)
# mape: tf.Tensor(47.13081453805363, shape=(), dtype=float64)
# mae: tf.Tensor(50.1678137135248, shape=(), dtype=float64)
# mse: tf.Tensor(3980.9594929378495, shape=(), dtype=float64)
# mape: tf.Tensor(46.11971924670032, shape=(), dtype=float64)
# mae: tf.Tensor(50.48500902912926, shape=(), dtype=float64)
# mse: tf.Tensor(4000.57983128939, shape=(), dtype=float64)
# mape: tf.Tensor(46.44786928547438, shape=(), dtype=float64)
# mae: tf.Tensor(50.451234406913066, shape=(), dtype=float64)
# mse: tf.Tensor(3994.487859264787, shape=(), dtype=float64)
# mape: tf.Tensor(46.43583948896276, shape=(), dtype=float64)
# mae: tf.Tensor(48.71401039664185, shape=(), dtype=float64)
# mse: tf.Tensor(3830.1243474150347, shape=(), dtype=float64)
# mape: tf.Tensor(44.92446134346418, shape=(), dtype=float64)
# mae: tf.Tensor(47.91468092297391, shape=(), dtype=float64)
# mse: tf.Tensor(3756.712181524979, shape=(), dtype=float64)
# mape: tf.Tensor(44.21428993003127, shape=(), dtype=float64)
# mae: tf.Tensor(46.235657446118395, shape=(), dtype=float64)
# mse: tf.Tensor(3612.1817237361356, shape=(), dtype=float64)
# mape: tf.Tensor(42.661015705332375, shape=(), dtype=float64)
# mae: tf.Tensor(46.328157237195114, shape=(), dtype=float64)
# mse: tf.Tensor(3618.704183645121, shape=(), dtype=float64)
# mape: tf.Tensor(42.76319835625442, shape=(), dtype=float64)
# mae: tf.Tensor(47.41248062672275, shape=(), dtype=float64)
# mse: tf.Tensor(3712.932137892238, shape=(), dtype=float64)
# mape: tf.Tensor(43.758895632590495, shape=(), dtype=float64)
# mae: tf.Tensor(48.260649023207954, shape=(), dtype=float64)
# mse: tf.Tensor(3786.8526210726045, shape=(), dtype=float64)
# mape: tf.Tensor(44.53102880688969, shape=(), dtype=float64)
# mae: tf.Tensor(48.22409432652537, shape=(), dtype=float64)
# mse: tf.Tensor(3785.4102408657213, shape=(), dtype=float64)
# mape: tf.Tensor(44.48175895940982, shape=(), dtype=float64)
# mae: tf.Tensor(48.24621466559917, shape=(), dtype=float64)
# mse: tf.Tensor(3785.885890339822, shape=(), dtype=float64)
# mape: tf.Tensor(44.51322853801854, shape=(), dtype=float64)
# mae: tf.Tensor(48.294760148198954, shape=(), dtype=float64)
# mse: tf.Tensor(3791.5624754064784, shape=(), dtype=float64)
# mape: tf.Tensor(44.54881587797867, shape=(), dtype=float64)
# mae: tf.Tensor(47.39018948541991, shape=(), dtype=float64)
# mse: tf.Tensor(3711.3391198383238, shape=(), dtype=float64)
# mape: tf.Tensor(43.734066736950304, shape=(), dtype=float64)
# mae: tf.Tensor(46.78338962010592, shape=(), dtype=float64)
# mse: tf.Tensor(3673.2813278539097, shape=(), dtype=float64)
# mape: tf.Tensor(43.00949881887622, shape=(), dtype=float64)
# mae: tf.Tensor(45.862144307441035, shape=(), dtype=float64)
# mse: tf.Tensor(3586.9794773651133, shape=(), dtype=float64)
# mape: tf.Tensor(42.25183961077587, shape=(), dtype=float64)
# mae: tf.Tensor(45.58654104533372, shape=(), dtype=float64)
# mse: tf.Tensor(3562.0083401246293, shape=(), dtype=float64)
# mape: tf.Tensor(41.99628681145712, shape=(), dtype=float64)
# mae: tf.Tensor(45.27057995173509, shape=(), dtype=float64)
# mse: tf.Tensor(3531.8394644261457, shape=(), dtype=float64)
# mape: tf.Tensor(41.73356832957064, shape=(), dtype=float64)
# mae: tf.Tensor(43.91250142297199, shape=(), dtype=float64)
# mse: tf.Tensor(3414.1445840702413, shape=(), dtype=float64)
# mape: tf.Tensor(40.48702390436633, shape=(), dtype=float64)
# mae: tf.Tensor(43.078409403051786, shape=(), dtype=float64)
# mse: tf.Tensor(3341.8580118863515, shape=(), dtype=float64)
# mape: tf.Tensor(39.72005024645165, shape=(), dtype=float64)
# mae: tf.Tensor(41.992782917368444, shape=(), dtype=float64)
# mse: tf.Tensor(3252.8467844155766, shape=(), dtype=float64)
# mape: tf.Tensor(38.66123438640731, shape=(), dtype=float64)
# mae: tf.Tensor(41.29160046310412, shape=(), dtype=float64)
# mse: tf.Tensor(3203.1939114596335, shape=(), dtype=float64)
# mape: tf.Tensor(37.799663541455104, shape=(), dtype=float64)
# mae: tf.Tensor(40.454812640069285, shape=(), dtype=float64)
# mse: tf.Tensor(3136.291423353155, shape=(), dtype=float64)
# mape: tf.Tensor(36.94163385295324, shape=(), dtype=float64)
# mae: tf.Tensor(39.99419788081692, shape=(), dtype=float64)
# mse: tf.Tensor(3095.678707701329, shape=(), dtype=float64)
# mape: tf.Tensor(36.535222902956335, shape=(), dtype=float64)
# mae: tf.Tensor(39.186333922382374, shape=(), dtype=float64)
# mse: tf.Tensor(3028.8334226216894, shape=(), dtype=float64)
# mape: tf.Tensor(35.73653796660402, shape=(), dtype=float64)
# mae: tf.Tensor(38.224701369929136, shape=(), dtype=float64)
# mse: tf.Tensor(2952.5999366221745, shape=(), dtype=float64)
# mape: tf.Tensor(34.72850738374969, shape=(), dtype=float64)
# mae: tf.Tensor(37.868967360592556, shape=(), dtype=float64)
# mse: tf.Tensor(2922.311049718133, shape=(), dtype=float64)
# mape: tf.Tensor(34.40864272438283, shape=(), dtype=float64)
# mae: tf.Tensor(37.018971428909715, shape=(), dtype=float64)
# mse: tf.Tensor(2859.3361585547564, shape=(), dtype=float64)
# mape: tf.Tensor(33.437623524726654, shape=(), dtype=float64)
# mae: tf.Tensor(36.71089699720814, shape=(), dtype=float64)
# mse: tf.Tensor(2837.2076019659116, shape=(), dtype=float64)
# mape: tf.Tensor(32.81105486449302, shape=(), dtype=float64)
# mae: tf.Tensor(36.324645228919536, shape=(), dtype=float64)
# mse: tf.Tensor(2807.152502403315, shape=(), dtype=float64)
# mape: tf.Tensor(32.231509053178705, shape=(), dtype=float64)
# mae: tf.Tensor(35.87051453611958, shape=(), dtype=float64)
# mse: tf.Tensor(2773.824286834222, shape=(), dtype=float64)
# mape: tf.Tensor(31.7710798634882, shape=(), dtype=float64)
# mae: tf.Tensor(35.42360610618285, shape=(), dtype=float64)
# mse: tf.Tensor(2741.3179805362042, shape=(), dtype=float64)
# mape: tf.Tensor(31.25796155620867, shape=(), dtype=float64)
# mae: tf.Tensor(35.0989261294064, shape=(), dtype=float64)
# mse: tf.Tensor(2714.874296036575, shape=(), dtype=float64)
# mape: tf.Tensor(30.66645695250865, shape=(), dtype=float64)
# mae: tf.Tensor(34.74639326581711, shape=(), dtype=float64)
# mse: tf.Tensor(2692.1064258807032, shape=(), dtype=float64)
# mape: tf.Tensor(30.36719304979244, shape=(), dtype=float64)
# mae: tf.Tensor(34.69540214461382, shape=(), dtype=float64)
# mse: tf.Tensor(2683.7806929031535, shape=(), dtype=float64)
# mape: tf.Tensor(29.95656840313312, shape=(), dtype=float64)
# mae: tf.Tensor(35.47277514898512, shape=(), dtype=float64)
# mse: tf.Tensor(2727.3607922912183, shape=(), dtype=float64)
# mape: tf.Tensor(30.167077134693827, shape=(), dtype=float64)
# mae: tf.Tensor(35.937854287890495, shape=(), dtype=float64)
# mse: tf.Tensor(2752.8005853926506, shape=(), dtype=float64)
# mape: tf.Tensor(30.20063165663205, shape=(), dtype=float64)
# mae: tf.Tensor(35.68453298461869, shape=(), dtype=float64)
# mse: tf.Tensor(2734.7887763502126, shape=(), dtype=float64)
# mape: tf.Tensor(29.9169243914024, shape=(), dtype=float64)
# mae: tf.Tensor(35.43820621670142, shape=(), dtype=float64)
# mse: tf.Tensor(2717.274464484131, shape=(), dtype=float64)
# mape: tf.Tensor(29.609634687131322, shape=(), dtype=float64)
# mae: tf.Tensor(35.80496103839229, shape=(), dtype=float64)
# mse: tf.Tensor(2735.608263470185, shape=(), dtype=float64)
# mape: tf.Tensor(29.56391442227853, shape=(), dtype=float64)
# mae: tf.Tensor(35.84429721385579, shape=(), dtype=float64)
# mse: tf.Tensor(2735.645769234286, shape=(), dtype=float64)
# mape: tf.Tensor(29.46627337951703, shape=(), dtype=float64)
# mae: tf.Tensor(36.760889893951266, shape=(), dtype=float64)
# mse: tf.Tensor(2791.8473862920077, shape=(), dtype=float64)
# mape: tf.Tensor(29.866051606950542, shape=(), dtype=float64)
# mae: tf.Tensor(38.04703714474288, shape=(), dtype=float64)
# mse: tf.Tensor(2884.6318710586415, shape=(), dtype=float64)
# mape: tf.Tensor(30.6352177452308, shape=(), dtype=float64)
# mae: tf.Tensor(37.92560293071998, shape=(), dtype=float64)
# mse: tf.Tensor(2868.582339321944, shape=(), dtype=float64)
# mape: tf.Tensor(30.467949014153977, shape=(), dtype=float64)
# mae: tf.Tensor(37.93156669712987, shape=(), dtype=float64)
# mse: tf.Tensor(2869.4275958741346, shape=(), dtype=float64)
# mape: tf.Tensor(30.46274499674879, shape=(), dtype=float64)
# mae: tf.Tensor(37.8427774732935, shape=(), dtype=float64)
# mse: tf.Tensor(2861.518150706438, shape=(), dtype=float64)
# mape: tf.Tensor(30.3860768562888, shape=(), dtype=float64)
# mae: tf.Tensor(38.20053004961677, shape=(), dtype=float64)
# mse: tf.Tensor(2882.0955598955175, shape=(), dtype=float64)
# mape: tf.Tensor(30.5331155429983, shape=(), dtype=float64)
# mae: tf.Tensor(38.32257267512658, shape=(), dtype=float64)
# mse: tf.Tensor(2890.1590970434395, shape=(), dtype=float64)
# mape: tf.Tensor(30.594337987496395, shape=(), dtype=float64)
# mae: tf.Tensor(38.85601475694615, shape=(), dtype=float64)
# mse: tf.Tensor(2926.8110963254003, shape=(), dtype=float64)
# mape: tf.Tensor(30.89021296280122, shape=(), dtype=float64)
# mae: tf.Tensor(39.27183593135859, shape=(), dtype=float64)
# mse: tf.Tensor(2958.3870595113713, shape=(), dtype=float64)
# mape: tf.Tensor(31.15102884376381, shape=(), dtype=float64)
# mae: tf.Tensor(38.90835197408139, shape=(), dtype=float64)
# mse: tf.Tensor(2929.542043725716, shape=(), dtype=float64)
# mape: tf.Tensor(30.91344430610144, shape=(), dtype=float64)
# mae: tf.Tensor(38.55216154808691, shape=(), dtype=float64)
# mse: tf.Tensor(2906.7488002154805, shape=(), dtype=float64)
# mape: tf.Tensor(30.72603100147345, shape=(), dtype=float64)
# mae: tf.Tensor(38.26010356302696, shape=(), dtype=float64)
# mse: tf.Tensor(2890.760879623729, shape=(), dtype=float64)
# mape: tf.Tensor(30.622582956222544, shape=(), dtype=float64)
# mae: tf.Tensor(38.24846175115859, shape=(), dtype=float64)
# mse: tf.Tensor(2887.04909103886, shape=(), dtype=float64)
# mape: tf.Tensor(30.57853589560393, shape=(), dtype=float64)
# mae: tf.Tensor(38.028900947658045, shape=(), dtype=float64)
# mse: tf.Tensor(2877.1186486458396, shape=(), dtype=float64)
# mape: tf.Tensor(30.532529935323247, shape=(), dtype=float64)
# mae: tf.Tensor(37.95660525320669, shape=(), dtype=float64)
# mse: tf.Tensor(2870.80499961044, shape=(), dtype=float64)
# mape: tf.Tensor(30.47905269933552, shape=(), dtype=float64)
# mae: tf.Tensor(37.727647482881885, shape=(), dtype=float64)
# mse: tf.Tensor(2859.470452192583, shape=(), dtype=float64)
# mape: tf.Tensor(30.415719045104865, shape=(), dtype=float64)
# mae: tf.Tensor(37.12548414028118, shape=(), dtype=float64)
# mse: tf.Tensor(2811.508334623012, shape=(), dtype=float64)
# mape: tf.Tensor(29.981602518701543, shape=(), dtype=float64)
# mae: tf.Tensor(36.166506594610205, shape=(), dtype=float64)
# mse: tf.Tensor(2754.2304718428154, shape=(), dtype=float64)
# mape: tf.Tensor(29.570826635163463, shape=(), dtype=float64)
# mae: tf.Tensor(36.02728225511321, shape=(), dtype=float64)
# mse: tf.Tensor(2751.585426896059, shape=(), dtype=float64)
# mape: tf.Tensor(29.741734976097728, shape=(), dtype=float64)
# mae: tf.Tensor(35.732179784403236, shape=(), dtype=float64)
# mse: tf.Tensor(2735.0789630748627, shape=(), dtype=float64)
# mape: tf.Tensor(29.70824551939401, shape=(), dtype=float64)
# mae: tf.Tensor(35.622625884846926, shape=(), dtype=float64)
# mse: tf.Tensor(2733.5501794858815, shape=(), dtype=float64)
# mape: tf.Tensor(29.955111471828122, shape=(), dtype=float64)
# mae: tf.Tensor(35.31903714022159, shape=(), dtype=float64)
# mse: tf.Tensor(2716.2630601344013, shape=(), dtype=float64)
# mape: tf.Tensor(29.918981828573052, shape=(), dtype=float64)
# mae: tf.Tensor(35.08411252940152, shape=(), dtype=float64)
# mse: tf.Tensor(2702.7982512549697, shape=(), dtype=float64)
# mape: tf.Tensor(29.862470729800304, shape=(), dtype=float64)
# mae: tf.Tensor(34.6127960477712, shape=(), dtype=float64)
# mse: tf.Tensor(2675.104287231701, shape=(), dtype=float64)
# mape: tf.Tensor(29.621301825054008, shape=(), dtype=float64)
# mae: tf.Tensor(34.82123287517071, shape=(), dtype=float64)
# mse: tf.Tensor(2694.439667778347, shape=(), dtype=float64)
# mape: tf.Tensor(30.239322023787274, shape=(), dtype=float64)
# mae: tf.Tensor(35.64043639485365, shape=(), dtype=float64)
# mse: tf.Tensor(2754.5730913186258, shape=(), dtype=float64)
# mape: tf.Tensor(31.328375174398808, shape=(), dtype=float64)
# mae: tf.Tensor(36.16143187890153, shape=(), dtype=float64)
# mse: tf.Tensor(2793.848828989597, shape=(), dtype=float64)
# mape: tf.Tensor(32.04010025356775, shape=(), dtype=float64)
# mae: tf.Tensor(36.87792753553104, shape=(), dtype=float64)
# mse: tf.Tensor(2847.004254303404, shape=(), dtype=float64)
# mape: tf.Tensor(32.90903723270243, shape=(), dtype=float64)
# mae: tf.Tensor(36.91949747398221, shape=(), dtype=float64)
# mse: tf.Tensor(2851.915781607799, shape=(), dtype=float64)
# mape: tf.Tensor(33.0540372361765, shape=(), dtype=float64)
# mae: tf.Tensor(36.99472068627929, shape=(), dtype=float64)
# mse: tf.Tensor(2857.2691078895527, shape=(), dtype=float64)
# mape: tf.Tensor(33.29733359519321, shape=(), dtype=float64)
# mae: tf.Tensor(37.78179658228798, shape=(), dtype=float64)
# mse: tf.Tensor(2917.6288140737593, shape=(), dtype=float64)
# mape: tf.Tensor(34.26629774883721, shape=(), dtype=float64)
# mae: tf.Tensor(38.79930559568739, shape=(), dtype=float64)
# mse: tf.Tensor(2997.1363594817644, shape=(), dtype=float64)
# mape: tf.Tensor(35.367753204753456, shape=(), dtype=float64)
# mae: tf.Tensor(39.822026665590734, shape=(), dtype=float64)
# mse: tf.Tensor(3079.9550132622753, shape=(), dtype=float64)
# mape: tf.Tensor(36.40051211980667, shape=(), dtype=float64)
# mae: tf.Tensor(40.89398086816869, shape=(), dtype=float64)
# mse: tf.Tensor(3168.163134942103, shape=(), dtype=float64)
# mape: tf.Tensor(37.44861090633202, shape=(), dtype=float64)
# mae: tf.Tensor(42.82641641807566, shape=(), dtype=float64)
# mse: tf.Tensor(3330.573245542349, shape=(), dtype=float64)
# mape: tf.Tensor(39.29081236934993, shape=(), dtype=float64)
# mae: tf.Tensor(43.27872826072895, shape=(), dtype=float64)
# mse: tf.Tensor(3365.189448055195, shape=(), dtype=float64)
# mape: tf.Tensor(39.784790307233905, shape=(), dtype=float64)
# mae: tf.Tensor(43.57564540466899, shape=(), dtype=float64)
# mse: tf.Tensor(3387.96664131592, shape=(), dtype=float64)
# mape: tf.Tensor(40.11029305502224, shape=(), dtype=float64)
# mae: tf.Tensor(43.692599475310644, shape=(), dtype=float64)
# mse: tf.Tensor(3393.1563461315654, shape=(), dtype=float64)
# mape: tf.Tensor(40.30607627683297, shape=(), dtype=float64)
# mae: tf.Tensor(45.39373373599763, shape=(), dtype=float64)
# mse: tf.Tensor(3537.146710117553, shape=(), dtype=float64)
# mape: tf.Tensor(41.90770317955524, shape=(), dtype=float64)
# mae: tf.Tensor(47.11295280823538, shape=(), dtype=float64)
# mse: tf.Tensor(3691.2301740461967, shape=(), dtype=float64)
# mape: tf.Tensor(43.43654824905089, shape=(), dtype=float64)
# mae: tf.Tensor(48.04837653744485, shape=(), dtype=float64)
# mse: tf.Tensor(3773.7367203731337, shape=(), dtype=float64)
# mape: tf.Tensor(44.2907610128278, shape=(), dtype=float64)
# mae: tf.Tensor(49.99041464041096, shape=(), dtype=float64)
# mse: tf.Tensor(3955.4289151208673, shape=(), dtype=float64)
# mape: tf.Tensor(45.99163234461395, shape=(), dtype=float64)
# mae: tf.Tensor(50.46417188985325, shape=(), dtype=float64)
# mse: tf.Tensor(3995.8721013069176, shape=(), dtype=float64)
# mape: tf.Tensor(46.43965096331672, shape=(), dtype=float64)
# mae: tf.Tensor(50.95387650805021, shape=(), dtype=float64)
# mse: tf.Tensor(4039.0271420695817, shape=(), dtype=float64)
# mape: tf.Tensor(46.89262531893064, shape=(), dtype=float64)
# mae: tf.Tensor(50.506584332557566, shape=(), dtype=float64)
# mse: tf.Tensor(3987.3583220271353, shape=(), dtype=float64)
# mape: tf.Tensor(46.553940848529216, shape=(), dtype=float64)
# mae: tf.Tensor(51.07088722899149, shape=(), dtype=float64)
# mse: tf.Tensor(4041.472124325662, shape=(), dtype=float64)
# mape: tf.Tensor(47.045121528832645, shape=(), dtype=float64)
# mae: tf.Tensor(52.162828106611784, shape=(), dtype=float64)
# mse: tf.Tensor(4142.443148509383, shape=(), dtype=float64)
# mape: tf.Tensor(48.01148434774275, shape=(), dtype=float64)
# mae: tf.Tensor(51.95637286741443, shape=(), dtype=float64)
# mse: tf.Tensor(4120.16452203731, shape=(), dtype=float64)
# mape: tf.Tensor(47.84241138009519, shape=(), dtype=float64)
# mae: tf.Tensor(51.45582990760159, shape=(), dtype=float64)
# mse: tf.Tensor(4076.9263028154337, shape=(), dtype=float64)
# mape: tf.Tensor(47.385284984536234, shape=(), dtype=float64)
# mae: tf.Tensor(50.85079630368434, shape=(), dtype=float64)
# mse: tf.Tensor(4021.7474333149767, shape=(), dtype=float64)
# mape: tf.Tensor(46.84823697263819, shape=(), dtype=float64)
# mae: tf.Tensor(50.53600715894149, shape=(), dtype=float64)
# mse: tf.Tensor(3994.031323488262, shape=(), dtype=float64)
# mape: tf.Tensor(46.56525385561987, shape=(), dtype=float64)
# mae: tf.Tensor(50.86880511595131, shape=(), dtype=float64)
# mse: tf.Tensor(4019.9660538327435, shape=(), dtype=float64)
# mape: tf.Tensor(46.877310980897896, shape=(), dtype=float64)
# mae: tf.Tensor(53.51593691914544, shape=(), dtype=float64)
# mse: tf.Tensor(4266.495233882819, shape=(), dtype=float64)
# mape: tf.Tensor(49.20811935710808, shape=(), dtype=float64)
# mae: tf.Tensor(55.41452506505635, shape=(), dtype=float64)
# mse: tf.Tensor(4471.260300225239, shape=(), dtype=float64)
# mape: tf.Tensor(50.81596141869819, shape=(), dtype=float64)
# mae: tf.Tensor(56.26752167235841, shape=(), dtype=float64)
# mse: tf.Tensor(4552.719674177369, shape=(), dtype=float64)
# mape: tf.Tensor(51.56864030551033, shape=(), dtype=float64)
# mae: tf.Tensor(57.503080947836935, shape=(), dtype=float64)
# mse: tf.Tensor(4687.1229117333405, shape=(), dtype=float64)
# mape: tf.Tensor(52.6152858533429, shape=(), dtype=float64)
# mae: tf.Tensor(57.15329391798445, shape=(), dtype=float64)
# mse: tf.Tensor(4652.586817943386, shape=(), dtype=float64)
# mape: tf.Tensor(52.32111241653985, shape=(), dtype=float64)
# mae: tf.Tensor(57.103243484659394, shape=(), dtype=float64)
# mse: tf.Tensor(4643.5589303572715, shape=(), dtype=float64)
# mape: tf.Tensor(52.286415975455455, shape=(), dtype=float64)
# mae: tf.Tensor(59.235265709688676, shape=(), dtype=float64)
# mse: tf.Tensor(4840.208344847781, shape=(), dtype=float64)
# mape: tf.Tensor(54.16122528636982, shape=(), dtype=float64)
# mae: tf.Tensor(61.76941567393895, shape=(), dtype=float64)
# mse: tf.Tensor(5109.647421813738, shape=(), dtype=float64)
# mape: tf.Tensor(56.33136887866268, shape=(), dtype=float64)
# mae: tf.Tensor(63.718977320647014, shape=(), dtype=float64)
# mse: tf.Tensor(5359.0317795112305, shape=(), dtype=float64)
# mape: tf.Tensor(57.96487058169311, shape=(), dtype=float64)
# mae: tf.Tensor(65.65231471232893, shape=(), dtype=float64)
# mse: tf.Tensor(5603.40737903642, shape=(), dtype=float64)
# mape: tf.Tensor(59.60074069434732, shape=(), dtype=float64)
# mae: tf.Tensor(68.16818567829432, shape=(), dtype=float64)
# mse: tf.Tensor(5911.856234932615, shape=(), dtype=float64)
# mape: tf.Tensor(61.72949756780407, shape=(), dtype=float64)
# mae: tf.Tensor(69.08350179429743, shape=(), dtype=float64)
# mse: tf.Tensor(6010.4517330475455, shape=(), dtype=float64)
# mape: tf.Tensor(62.523774735842274, shape=(), dtype=float64)
# mae: tf.Tensor(69.62909583190559, shape=(), dtype=float64)
# mse: tf.Tensor(6073.803053316567, shape=(), dtype=float64)
# mape: tf.Tensor(62.99480219909585, shape=(), dtype=float64)
# mae: tf.Tensor(68.48726454146829, shape=(), dtype=float64)
# mse: tf.Tensor(5918.624601903699, shape=(), dtype=float64)
# mape: tf.Tensor(62.0334370818689, shape=(), dtype=float64)
# mae: tf.Tensor(72.26893011119896, shape=(), dtype=float64)
# mse: tf.Tensor(6360.038446187312, shape=(), dtype=float64)
# mape: tf.Tensor(65.2413962600884, shape=(), dtype=float64)
# mae: tf.Tensor(72.88310073678944, shape=(), dtype=float64)
# mse: tf.Tensor(6447.758983061336, shape=(), dtype=float64)
# mape: tf.Tensor(65.76079068217759, shape=(), dtype=float64)
# mae: tf.Tensor(72.2916486557691, shape=(), dtype=float64)
# mse: tf.Tensor(6361.095435243606, shape=(), dtype=float64)
# mape: tf.Tensor(65.26060897531121, shape=(), dtype=float64)
# mae: tf.Tensor(71.23391163443934, shape=(), dtype=float64)
# mse: tf.Tensor(6231.468169588075, shape=(), dtype=float64)
# mape: tf.Tensor(64.36431246883035, shape=(), dtype=float64)
# mae: tf.Tensor(70.44783797530667, shape=(), dtype=float64)
# mse: tf.Tensor(6145.79555503976, shape=(), dtype=float64)
# mape: tf.Tensor(63.695048348409344, shape=(), dtype=float64)
# mae: tf.Tensor(69.89035814794998, shape=(), dtype=float64)
# mse: tf.Tensor(6083.26386090927, shape=(), dtype=float64)
# mape: tf.Tensor(63.22443862912226, shape=(), dtype=float64)
# mae: tf.Tensor(71.5255713908504, shape=(), dtype=float64)
# mse: tf.Tensor(6256.586031462419, shape=(), dtype=float64)
# mape: tf.Tensor(64.61274950156059, shape=(), dtype=float64)
# mae: tf.Tensor(74.49794127275527, shape=(), dtype=float64)
# mse: tf.Tensor(6656.879450019872, shape=(), dtype=float64)
# mape: tf.Tensor(67.12643588238222, shape=(), dtype=float64)
# mae: tf.Tensor(75.5100777427128, shape=(), dtype=float64)
# mse: tf.Tensor(6805.7445026520245, shape=(), dtype=float64)
# mape: tf.Tensor(67.98238374928586, shape=(), dtype=float64)
# mae: tf.Tensor(78.15570844339095, shape=(), dtype=float64)
# mse: tf.Tensor(7237.1146615098905, shape=(), dtype=float64)
# mape: tf.Tensor(70.21961758080802, shape=(), dtype=float64)
# mae: tf.Tensor(82.13330708655704, shape=(), dtype=float64)
# mse: tf.Tensor(7898.398144899138, shape=(), dtype=float64)
# mape: tf.Tensor(73.58293486126435, shape=(), dtype=float64)
# mae: tf.Tensor(83.49835969513794, shape=(), dtype=float64)
# mse: tf.Tensor(8068.997339356345, shape=(), dtype=float64)
# mape: tf.Tensor(74.73794794478425, shape=(), dtype=float64)
# mae: tf.Tensor(84.71916588738792, shape=(), dtype=float64)
# mse: tf.Tensor(8211.209710866979, shape=(), dtype=float64)
# mape: tf.Tensor(75.77036450833616, shape=(), dtype=float64)
# mae: tf.Tensor(84.36359215213774, shape=(), dtype=float64)
# mse: tf.Tensor(8090.590559831207, shape=(), dtype=float64)
# mape: tf.Tensor(75.46966140233391, shape=(), dtype=float64)
# mae: tf.Tensor(88.63230539405929, shape=(), dtype=float64)
# mse: tf.Tensor(8788.075677168163, shape=(), dtype=float64)
# mape: tf.Tensor(79.07964493943487, shape=(), dtype=float64)
# mae: tf.Tensor(89.8493446029775, shape=(), dtype=float64)
# mse: tf.Tensor(9012.664240496, shape=(), dtype=float64)
# mape: tf.Tensor(80.10887582453014, shape=(), dtype=float64)
# mae: tf.Tensor(92.28688763039482, shape=(), dtype=float64)
# mse: tf.Tensor(9427.82365253661, shape=(), dtype=float64)
# mape: tf.Tensor(82.1702675604601, shape=(), dtype=float64)
# mae: tf.Tensor(94.17376137795661, shape=(), dtype=float64)
# mse: tf.Tensor(9798.946745254603, shape=(), dtype=float64)
# mape: tf.Tensor(83.76596696195456, shape=(), dtype=float64)
# mae: tf.Tensor(93.1436828173937, shape=(), dtype=float64)
# mse: tf.Tensor(9602.087666477033, shape=(), dtype=float64)
# mape: tf.Tensor(82.89484575169533, shape=(), dtype=float64)
# mae: tf.Tensor(94.26656777097713, shape=(), dtype=float64)
# mse: tf.Tensor(9822.22074885335, shape=(), dtype=float64)
# mape: tf.Tensor(83.8444518664105, shape=(), dtype=float64)
# mae: tf.Tensor(94.85518609111018, shape=(), dtype=float64)
# mse: tf.Tensor(9861.784245457407, shape=(), dtype=float64)
# mape: tf.Tensor(84.34223710633913, shape=(), dtype=float64)
# mae: tf.Tensor(97.43564321462489, shape=(), dtype=float64)
# mse: tf.Tensor(10345.982674540342, shape=(), dtype=float64)
# mape: tf.Tensor(86.52448904179342, shape=(), dtype=float64)
# mae: tf.Tensor(99.05971108593127, shape=(), dtype=float64)
# mse: tf.Tensor(10689.272418254419, shape=(), dtype=float64)
# mape: tf.Tensor(87.89793765412308, shape=(), dtype=float64)
# mae: tf.Tensor(99.6795033606228, shape=(), dtype=float64)
# mse: tf.Tensor(10797.4663570422, shape=(), dtype=float64)
# mape: tf.Tensor(88.42208621629062, shape=(), dtype=float64)
# mae: tf.Tensor(101.026449621912, shape=(), dtype=float64)
# mse: tf.Tensor(11091.033876069783, shape=(), dtype=float64)
# mape: tf.Tensor(89.56117744895091, shape=(), dtype=float64)
# mae: tf.Tensor(99.84588905441771, shape=(), dtype=float64)
# mse: tf.Tensor(10856.747968554206, shape=(), dtype=float64)
# mape: tf.Tensor(88.5627959762038, shape=(), dtype=float64)
# mae: tf.Tensor(98.96517880783863, shape=(), dtype=float64)
# mse: tf.Tensor(10713.787039530645, shape=(), dtype=float64)
# mape: tf.Tensor(87.81799319585224, shape=(), dtype=float64)
# mae: tf.Tensor(100.55498266942762, shape=(), dtype=float64)
# mse: tf.Tensor(10957.722599882605, shape=(), dtype=float64)
# mape: tf.Tensor(89.16246527497749, shape=(), dtype=float64)
# mae: tf.Tensor(101.73665161145682, shape=(), dtype=float64)
# mse: tf.Tensor(11197.208985202067, shape=(), dtype=float64)
# mape: tf.Tensor(90.16178408260687, shape=(), dtype=float64)
# mae: tf.Tensor(102.52548074776806, shape=(), dtype=float64)
# mse: tf.Tensor(11367.163047543148, shape=(), dtype=float64)
# mape: tf.Tensor(90.82888445554909, shape=(), dtype=float64)
# mae: tf.Tensor(104.61589859310723, shape=(), dtype=float64)
# mse: tf.Tensor(11841.671853201637, shape=(), dtype=float64)
# mape: tf.Tensor(92.59671789379132, shape=(), dtype=float64)
# mae: tf.Tensor(105.7059983471164, shape=(), dtype=float64)
# mse: tf.Tensor(12057.874189700255, shape=(), dtype=float64)
# mape: tf.Tensor(93.51859808174217, shape=(), dtype=float64)
# mae: tf.Tensor(105.35864015547631, shape=(), dtype=float64)
# mse: tf.Tensor(11972.188564024089, shape=(), dtype=float64)
# mape: tf.Tensor(93.22484273153893, shape=(), dtype=float64)
# mae: tf.Tensor(105.73235081700304, shape=(), dtype=float64)
# mse: tf.Tensor(12037.026813570972, shape=(), dtype=float64)
# mape: tf.Tensor(93.54088395035444, shape=(), dtype=float64)
# mae: tf.Tensor(105.36481125368402, shape=(), dtype=float64)
# mse: tf.Tensor(11964.757465408615, shape=(), dtype=float64)
# mape: tf.Tensor(93.2300615320704, shape=(), dtype=float64)
# mae: tf.Tensor(107.22095143024583, shape=(), dtype=float64)
# mse: tf.Tensor(12321.743714865368, shape=(), dtype=float64)
# mape: tf.Tensor(94.79977003676339, shape=(), dtype=float64)
# mae: tf.Tensor(105.18553073843964, shape=(), dtype=float64)
# mse: tf.Tensor(11917.092744195377, shape=(), dtype=float64)
# mape: tf.Tensor(93.07844682480939, shape=(), dtype=float64)
# mae: tf.Tensor(101.18616796292176, shape=(), dtype=float64)
# mse: tf.Tensor(11110.949978062092, shape=(), dtype=float64)
# mape: tf.Tensor(89.69624873365471, shape=(), dtype=float64)
# mae: tf.Tensor(98.76913757656334, shape=(), dtype=float64)
# mse: tf.Tensor(10611.346524427352, shape=(), dtype=float64)
# mape: tf.Tensor(87.65220421510125, shape=(), dtype=float64)
# mae: tf.Tensor(96.84199294498127, shape=(), dtype=float64)
# mse: tf.Tensor(10233.878285285373, shape=(), dtype=float64)
# mape: tf.Tensor(86.02244836143977, shape=(), dtype=float64)
# mae: tf.Tensor(90.68720429203489, shape=(), dtype=float64)
# mse: tf.Tensor(9216.07833503554, shape=(), dtype=float64)
# mape: tf.Tensor(80.81744056347625, shape=(), dtype=float64)
# mae: tf.Tensor(90.85360171674242, shape=(), dtype=float64)
# mse: tf.Tensor(9209.166993501947, shape=(), dtype=float64)
# mape: tf.Tensor(80.95816024403737, shape=(), dtype=float64)
# mae: tf.Tensor(89.60837850573739, shape=(), dtype=float64)
# mse: tf.Tensor(8984.393675320844, shape=(), dtype=float64)
# mape: tf.Tensor(79.90509459240302, shape=(), dtype=float64)
# mae: tf.Tensor(90.18499889092305, shape=(), dtype=float64)
# mse: tf.Tensor(9066.113696277345, shape=(), dtype=float64)
# mape: tf.Tensor(80.39273336776851, shape=(), dtype=float64)
# mae: tf.Tensor(88.79649801044283, shape=(), dtype=float64)
# mse: tf.Tensor(8825.018646129063, shape=(), dtype=float64)
# mape: tf.Tensor(79.21850004833212, shape=(), dtype=float64)
# mae: tf.Tensor(88.12666803028414, shape=(), dtype=float64)
# mse: tf.Tensor(8714.35014121412, shape=(), dtype=float64)
# mape: tf.Tensor(78.65203538697176, shape=(), dtype=float64)
# mae: tf.Tensor(86.24222478849957, shape=(), dtype=float64)
# mse: tf.Tensor(8414.237507453063, shape=(), dtype=float64)
# mape: tf.Tensor(77.05839142592153, shape=(), dtype=float64)
# mae: tf.Tensor(84.48189271659606, shape=(), dtype=float64)
# mse: tf.Tensor(8187.128620430107, shape=(), dtype=float64)
# mape: tf.Tensor(75.56970632592599, shape=(), dtype=float64)
# mae: tf.Tensor(84.01226714630154, shape=(), dtype=float64)
# mse: tf.Tensor(8086.345858338992, shape=(), dtype=float64)
# mape: tf.Tensor(75.1725513798604, shape=(), dtype=float64)
# mae: tf.Tensor(84.56113177678728, shape=(), dtype=float64)
# mse: tf.Tensor(8169.153743887947, shape=(), dtype=float64)
# mape: tf.Tensor(75.63671755075515, shape=(), dtype=float64)
# mae: tf.Tensor(83.34272342672081, shape=(), dtype=float64)
# mse: tf.Tensor(7962.360090055055, shape=(), dtype=float64)
# mape: tf.Tensor(74.60632880456092, shape=(), dtype=float64)
# mae: tf.Tensor(81.75086204547078, shape=(), dtype=float64)
# mse: tf.Tensor(7699.492884896866, shape=(), dtype=float64)
# mape: tf.Tensor(73.2601167134736, shape=(), dtype=float64)
# mae: tf.Tensor(80.221792086921, shape=(), dtype=float64)
# mse: tf.Tensor(7457.407008356823, shape=(), dtype=float64)
# mape: tf.Tensor(71.96700633931424, shape=(), dtype=float64)
# mae: tf.Tensor(77.25507214197124, shape=(), dtype=float64)
# mse: tf.Tensor(7057.476268854578, shape=(), dtype=float64)
# mape: tf.Tensor(69.45809802116341, shape=(), dtype=float64)
# mae: tf.Tensor(73.08936681365547, shape=(), dtype=float64)
# mse: tf.Tensor(6589.408233986016, shape=(), dtype=float64)
# mape: tf.Tensor(65.91094791377681, shape=(), dtype=float64)
# mae: tf.Tensor(70.56809106548413, shape=(), dtype=float64)
# mse: tf.Tensor(6260.544557568096, shape=(), dtype=float64)
# mape: tf.Tensor(63.78120750295699, shape=(), dtype=float64)
# mae: tf.Tensor(70.09459749859622, shape=(), dtype=float64)
# mse: tf.Tensor(6177.902216079039, shape=(), dtype=float64)
# mape: tf.Tensor(63.38219898275804, shape=(), dtype=float64)
# mae: tf.Tensor(68.104605502036, shape=(), dtype=float64)
# mse: tf.Tensor(5891.846279676244, shape=(), dtype=float64)
# mape: tf.Tensor(61.70694284874892, shape=(), dtype=float64)
# mae: tf.Tensor(64.6284893747059, shape=(), dtype=float64)
# mse: tf.Tensor(5462.657199880746, shape=(), dtype=float64)
# mape: tf.Tensor(58.75417518946648, shape=(), dtype=float64)
# mae: tf.Tensor(62.90483855344205, shape=(), dtype=float64)
# mse: tf.Tensor(5233.239644528803, shape=(), dtype=float64)
# mape: tf.Tensor(57.30248814117968, shape=(), dtype=float64)
# mae: tf.Tensor(61.516185963815204, shape=(), dtype=float64)
# mse: tf.Tensor(5079.160289894371, shape=(), dtype=float64)
# mape: tf.Tensor(56.119198121177206, shape=(), dtype=float64)
# mae: tf.Tensor(59.73316404860855, shape=(), dtype=float64)
# mse: tf.Tensor(4896.32885977683, shape=(), dtype=float64)
# mape: tf.Tensor(54.58152013184316, shape=(), dtype=float64)
# mae: tf.Tensor(59.26393514118025, shape=(), dtype=float64)
# mse: tf.Tensor(4853.443691985843, shape=(), dtype=float64)
# mape: tf.Tensor(54.16948821214107, shape=(), dtype=float64)
# mae: tf.Tensor(57.57941180214673, shape=(), dtype=float64)
# mse: tf.Tensor(4692.896515048314, shape=(), dtype=float64)
# mape: tf.Tensor(52.69385551064554, shape=(), dtype=float64)
# mae: tf.Tensor(55.84795550388859, shape=(), dtype=float64)
# mse: tf.Tensor(4504.910118130957, shape=(), dtype=float64)
# mape: tf.Tensor(51.223120597160005, shape=(), dtype=float64)
# mae: tf.Tensor(55.37147282101153, shape=(), dtype=float64)
# mse: tf.Tensor(4449.245275157553, shape=(), dtype=float64)
# mape: tf.Tensor(50.82067436431529, shape=(), dtype=float64)
# mae: tf.Tensor(55.07606428342077, shape=(), dtype=float64)
# mse: tf.Tensor(4416.831899542926, shape=(), dtype=float64)
# mape: tf.Tensor(50.57245995051415, shape=(), dtype=float64)
# mae: tf.Tensor(53.183075207627994, shape=(), dtype=float64)
# mse: tf.Tensor(4231.412647915323, shape=(), dtype=float64)
# mape: tf.Tensor(48.926310732218894, shape=(), dtype=float64)
# mae: tf.Tensor(52.848927712113905, shape=(), dtype=float64)
# mse: tf.Tensor(4204.160522877395, shape=(), dtype=float64)
# mape: tf.Tensor(48.619562491820595, shape=(), dtype=float64)
# mae: tf.Tensor(52.40829012017338, shape=(), dtype=float64)
# mse: tf.Tensor(4162.002055493671, shape=(), dtype=float64)
# mape: tf.Tensor(48.23517318049852, shape=(), dtype=float64)
# mae: tf.Tensor(53.29718570070198, shape=(), dtype=float64)
# mse: tf.Tensor(4242.9291034226035, shape=(), dtype=float64)
# mape: tf.Tensor(49.023589462751126, shape=(), dtype=float64)
# mae: tf.Tensor(53.791695932647805, shape=(), dtype=float64)
# mse: tf.Tensor(4292.946157982623, shape=(), dtype=float64)
# mape: tf.Tensor(49.448497625730326, shape=(), dtype=float64)
# mae: tf.Tensor(53.37666048671146, shape=(), dtype=float64)
# mse: tf.Tensor(4256.21326603727, shape=(), dtype=float64)
# mape: tf.Tensor(49.072858763282845, shape=(), dtype=float64)
# mae: tf.Tensor(54.2178694397008, shape=(), dtype=float64)
# mse: tf.Tensor(4336.633973685757, shape=(), dtype=float64)
# mape: tf.Tensor(49.811487706960975, shape=(), dtype=float64)
# mae: tf.Tensor(52.768332531986054, shape=(), dtype=float64)
# mse: tf.Tensor(4204.22784468413, shape=(), dtype=float64)
# mape: tf.Tensor(48.533525024728476, shape=(), dtype=float64)
# mae: tf.Tensor(52.60822862157002, shape=(), dtype=float64)
# mse: tf.Tensor(4210.075528236949, shape=(), dtype=float64)
# mape: tf.Tensor(48.29624485333238, shape=(), dtype=float64)
# mae: tf.Tensor(52.55908861987087, shape=(), dtype=float64)
# mse: tf.Tensor(4189.091332342794, shape=(), dtype=float64)
# mape: tf.Tensor(48.32883319994048, shape=(), dtype=float64)
# mae: tf.Tensor(53.61126443638195, shape=(), dtype=float64)
# mse: tf.Tensor(4289.907533838972, shape=(), dtype=float64)
# mape: tf.Tensor(49.24009865426428, shape=(), dtype=float64)
# mae: tf.Tensor(53.889168433305564, shape=(), dtype=float64)
# mse: tf.Tensor(4315.989671360274, shape=(), dtype=float64)
# mape: tf.Tensor(49.48856397484474, shape=(), dtype=float64)
# mae: tf.Tensor(53.59201518564876, shape=(), dtype=float64)
# mse: tf.Tensor(4289.921638562005, shape=(), dtype=float64)
# mape: tf.Tensor(49.22195571630706, shape=(), dtype=float64)
# mae: tf.Tensor(55.12098592334086, shape=(), dtype=float64)
# mse: tf.Tensor(4445.171080842921, shape=(), dtype=float64)
# mape: tf.Tensor(50.528604415203084, shape=(), dtype=float64)
# mae: tf.Tensor(54.36587679790662, shape=(), dtype=float64)
# mse: tf.Tensor(4376.457145912746, shape=(), dtype=float64)
# mape: tf.Tensor(49.88015256869328, shape=(), dtype=float64)
# mae: tf.Tensor(54.04051493944246, shape=(), dtype=float64)
# mse: tf.Tensor(4353.203957347824, shape=(), dtype=float64)
# mape: tf.Tensor(49.560745772494556, shape=(), dtype=float64)
# mae: tf.Tensor(55.8689915005276, shape=(), dtype=float64)
# mse: tf.Tensor(4500.928827374059, shape=(), dtype=float64)
# mape: tf.Tensor(51.250327698243325, shape=(), dtype=float64)
# mae: tf.Tensor(58.07690279321572, shape=(), dtype=float64)
# mse: tf.Tensor(4726.541170782908, shape=(), dtype=float64)
# mape: tf.Tensor(53.15277258765685, shape=(), dtype=float64)
# mae: tf.Tensor(59.24419223073735, shape=(), dtype=float64)
# mse: tf.Tensor(4864.672989288863, shape=(), dtype=float64)
# mape: tf.Tensor(54.12949926599769, shape=(), dtype=float64)
# mae: tf.Tensor(60.34589383570839, shape=(), dtype=float64)
# mse: tf.Tensor(4998.797219183886, shape=(), dtype=float64)
# mape: tf.Tensor(55.05073928078259, shape=(), dtype=float64)
# mae: tf.Tensor(63.43872364784818, shape=(), dtype=float64)
# mse: tf.Tensor(5354.02799238703, shape=(), dtype=float64)
# mape: tf.Tensor(57.674600111089894, shape=(), dtype=float64)
# mae: tf.Tensor(64.54826644039977, shape=(), dtype=float64)
# mse: tf.Tensor(5474.593811822116, shape=(), dtype=float64)
# mape: tf.Tensor(58.64644208356846, shape=(), dtype=float64)
# mae: tf.Tensor(65.89114238822293, shape=(), dtype=float64)
# mse: tf.Tensor(5620.337935131917, shape=(), dtype=float64)
# mape: tf.Tensor(59.807158671151974, shape=(), dtype=float64)
# mae: tf.Tensor(67.7888154866823, shape=(), dtype=float64)
# mse: tf.Tensor(5803.89276051322, shape=(), dtype=float64)
# mape: tf.Tensor(61.44668880526621, shape=(), dtype=float64)
# mae: tf.Tensor(67.75709718860422, shape=(), dtype=float64)
# mse: tf.Tensor(5783.706643908542, shape=(), dtype=float64)
# mape: tf.Tensor(61.42329898495328, shape=(), dtype=float64)
# mae: tf.Tensor(69.30430105731205, shape=(), dtype=float64)
# mse: tf.Tensor(5969.370076928589, shape=(), dtype=float64)
# mape: tf.Tensor(62.73425617556838, shape=(), dtype=float64)
# mae: tf.Tensor(70.31803281163866, shape=(), dtype=float64)
# mse: tf.Tensor(6113.8185447935075, shape=(), dtype=float64)
# mape: tf.Tensor(63.59147741952988, shape=(), dtype=float64)
# mae: tf.Tensor(72.7886553981931, shape=(), dtype=float64)
# mse: tf.Tensor(6478.604127571015, shape=(), dtype=float64)
# mape: tf.Tensor(65.68000869910888, shape=(), dtype=float64)
# mae: tf.Tensor(74.36396109483256, shape=(), dtype=float64)
# mse: tf.Tensor(6682.07517978028, shape=(), dtype=float64)
# mape: tf.Tensor(67.01289428018565, shape=(), dtype=float64)
# mae: tf.Tensor(75.36182513337184, shape=(), dtype=float64)
# mse: tf.Tensor(6789.4569196615985, shape=(), dtype=float64)
# mape: tf.Tensor(67.85698930553191, shape=(), dtype=float64)
# mae: tf.Tensor(80.61805483907959, shape=(), dtype=float64)
# mse: tf.Tensor(7560.319144344627, shape=(), dtype=float64)
# mape: tf.Tensor(72.30211950587938, shape=(), dtype=float64)
# mae: tf.Tensor(84.00277031758814, shape=(), dtype=float64)
# mse: tf.Tensor(8076.672841978865, shape=(), dtype=float64)
# mape: tf.Tensor(75.16452006143558, shape=(), dtype=float64)
# mae: tf.Tensor(88.73548430463403, shape=(), dtype=float64)
# mse: tf.Tensor(8911.572219666274, shape=(), dtype=float64)
# mape: tf.Tensor(79.16690171857219, shape=(), dtype=float64)
# mae: tf.Tensor(91.18131168258844, shape=(), dtype=float64)
# mse: tf.Tensor(9300.825612028153, shape=(), dtype=float64)
# mape: tf.Tensor(81.23529939923516, shape=(), dtype=float64)
# mae: tf.Tensor(95.49751949995641, shape=(), dtype=float64)
# mse: tf.Tensor(10107.660118570546, shape=(), dtype=float64)
# mape: tf.Tensor(84.88544835053618, shape=(), dtype=float64)
# mae: tf.Tensor(95.68728011304913, shape=(), dtype=float64)
# mse: tf.Tensor(10082.878889176542, shape=(), dtype=float64)
# mape: tf.Tensor(85.04592591143847, shape=(), dtype=float64)
# mae: tf.Tensor(95.86327161139643, shape=(), dtype=float64)
# mse: tf.Tensor(10109.938426177894, shape=(), dtype=float64)
# mape: tf.Tensor(85.19475914892658, shape=(), dtype=float64)
# mae: tf.Tensor(97.2924418511722, shape=(), dtype=float64)
# mse: tf.Tensor(10315.922906538, shape=(), dtype=float64)
# mape: tf.Tensor(86.4033859047924, shape=(), dtype=float64)
# mae: tf.Tensor(100.59588972747393, shape=(), dtype=float64)
# mse: tf.Tensor(10950.52115360978, shape=(), dtype=float64)
# mape: tf.Tensor(89.19705972949559, shape=(), dtype=float64)
# mae: tf.Tensor(101.70551913101893, shape=(), dtype=float64)
# mse: tf.Tensor(11198.26675913471, shape=(), dtype=float64)
# mape: tf.Tensor(90.1354558343783, shape=(), dtype=float64)
# mae: tf.Tensor(101.54621051003795, shape=(), dtype=float64)
# mse: tf.Tensor(11150.971076550619, shape=(), dtype=float64)
# mape: tf.Tensor(90.00073104344801, shape=(), dtype=float64)
# mae: tf.Tensor(102.04234883213668, shape=(), dtype=float64)
# mse: tf.Tensor(11260.313378014533, shape=(), dtype=float64)
# mape: tf.Tensor(90.42030740601828, shape=(), dtype=float64)
# mae: tf.Tensor(100.62207528492779, shape=(), dtype=float64)
# mse: tf.Tensor(10995.863399331038, shape=(), dtype=float64)
# mape: tf.Tensor(89.21920444289306, shape=(), dtype=float64)
# mae: tf.Tensor(99.34561832131892, shape=(), dtype=float64)
# mse: tf.Tensor(10776.483026028709, shape=(), dtype=float64)
# mape: tf.Tensor(88.13972489875493, shape=(), dtype=float64)
# mae: tf.Tensor(100.07691677234723, shape=(), dtype=float64)
# mse: tf.Tensor(10879.621164082553, shape=(), dtype=float64)
# mape: tf.Tensor(88.75817247752249, shape=(), dtype=float64)
# mae: tf.Tensor(102.19250680459251, shape=(), dtype=float64)
# mse: tf.Tensor(11300.007096091587, shape=(), dtype=float64)
# mape: tf.Tensor(90.54729363765516, shape=(), dtype=float64)
# mae: tf.Tensor(102.76355076945018, shape=(), dtype=float64)
# mse: tf.Tensor(11406.758011065804, shape=(), dtype=float64)
# mape: tf.Tensor(91.03021652220316, shape=(), dtype=float64)
# mae: tf.Tensor(101.75203661581496, shape=(), dtype=float64)
# mse: tf.Tensor(11194.457526379434, shape=(), dtype=float64)
# mape: tf.Tensor(90.174794938409, shape=(), dtype=float64)
# mae: tf.Tensor(101.9407072703616, shape=(), dtype=float64)
# mse: tf.Tensor(11242.358656176531, shape=(), dtype=float64)
# mape: tf.Tensor(90.33435073854066, shape=(), dtype=float64)
# mae: tf.Tensor(100.18347349783987, shape=(), dtype=float64)
# mse: tf.Tensor(10915.927407152563, shape=(), dtype=float64)
# mape: tf.Tensor(88.84828582151997, shape=(), dtype=float64)
# mae: tf.Tensor(98.85515013951294, shape=(), dtype=float64)
# mse: tf.Tensor(10684.878443695554, shape=(), dtype=float64)
# ...
# mae: tf.Tensor(38.356498579988624, shape=(), dtype=float64)
# mse: tf.Tensor(2889.6535351987513, shape=(), dtype=float64)
# mape: tf.Tensor(30.5831327563505, shape=(), dtype=float64)
# mae: tf.Tensor(37.56672617243258, shape=(), dtype=float64)
# mse: tf.Tensor(2838.860738599173, shape=(), dtype=float64)
# mape: tf.Tensor(30.184871260286094, shape=(), dtype=float64)
# mae: tf.Tensor(37.20932623008136, shape=(), dtype=float64)
# mse: tf.Tensor(2820.5524526619392, shape=(), dtype=float64)
# mape: tf.Tensor(30.078024484665388, shape=(), dtype=float64)
# mae: tf.Tensor(37.02215185685748, shape=(), dtype=float64)
# mse: tf.Tensor(2808.540244236439, shape=(), dtype=float64)
# mape: tf.Tensor(29.992448087856715, shape=(), dtype=float64)
# mae: tf.Tensor(36.799907989419985, shape=(), dtype=float64)
# mse: tf.Tensor(2795.7586305118134, shape=(), dtype=float64)
# mape: tf.Tensor(29.908749250695855, shape=(), dtype=float64)
# mae: tf.Tensor(36.884966996354294, shape=(), dtype=float64)
# mse: tf.Tensor(2800.438754525212, shape=(), dtype=float64)
# mape: tf.Tensor(29.953932484316223, shape=(), dtype=float64)
# mae: tf.Tensor(36.93808402782147, shape=(), dtype=float64)
# mse: tf.Tensor(2803.078727776666, shape=(), dtype=float64)
# mape: tf.Tensor(29.97753302438003, shape=(), dtype=float64)
# mae: tf.Tensor(36.62760437736757, shape=(), dtype=float64)
# mse: tf.Tensor(2782.479755832748, shape=(), dtype=float64)
# mape: tf.Tensor(29.803831582749314, shape=(), dtype=float64)
# mae: tf.Tensor(36.29136820726783, shape=(), dtype=float64)
# mse: tf.Tensor(2763.551886921938, shape=(), dtype=float64)
# mape: tf.Tensor(29.678904799073557, shape=(), dtype=float64)
# mae: tf.Tensor(36.17623705525337, shape=(), dtype=float64)
# mse: tf.Tensor(2756.9676395305064, shape=(), dtype=float64)
# mape: tf.Tensor(29.64439920267521, shape=(), dtype=float64)
# mae: tf.Tensor(36.1974294451319, shape=(), dtype=float64)
# mse: tf.Tensor(2757.5361001010815, shape=(), dtype=float64)
# mape: tf.Tensor(29.633688900287837, shape=(), dtype=float64)
# mae: tf.Tensor(36.131995711154765, shape=(), dtype=float64)
# mse: tf.Tensor(2755.266259347333, shape=(), dtype=float64)
# mape: tf.Tensor(29.64199085945067, shape=(), dtype=float64)
# mae: tf.Tensor(36.32493969770523, shape=(), dtype=float64)
# mse: tf.Tensor(2766.0296403110465, shape=(), dtype=float64)
# mape: tf.Tensor(29.72841116869267, shape=(), dtype=float64)
# mae: tf.Tensor(36.57195600253914, shape=(), dtype=float64)
# mse: tf.Tensor(2782.5681278372263, shape=(), dtype=float64)
# mape: tf.Tensor(29.860188853845933, shape=(), dtype=float64)
# mae: tf.Tensor(36.05992551238982, shape=(), dtype=float64)
# mse: tf.Tensor(2748.9861415968885, shape=(), dtype=float64)
# mape: tf.Tensor(29.574252357696526, shape=(), dtype=float64)
# mae: tf.Tensor(35.76413909629801, shape=(), dtype=float64)
# mse: tf.Tensor(2732.7376651965888, shape=(), dtype=float64)
# mape: tf.Tensor(29.483326765258425, shape=(), dtype=float64)
# mae: tf.Tensor(35.68736430511267, shape=(), dtype=float64)
# mse: tf.Tensor(2729.6144786214836, shape=(), dtype=float64)
# mape: tf.Tensor(29.5321726940435, shape=(), dtype=float64)
# mae: tf.Tensor(35.70292322552852, shape=(), dtype=float64)
# mse: tf.Tensor(2730.5032392902863, shape=(), dtype=float64)
# mape: tf.Tensor(29.535300897945447, shape=(), dtype=float64)
# mae: tf.Tensor(35.5703908012021, shape=(), dtype=float64)
# mse: tf.Tensor(2724.9280823901186, shape=(), dtype=float64)
# mape: tf.Tensor(29.581324632020667, shape=(), dtype=float64)
# mae: tf.Tensor(35.66950380565765, shape=(), dtype=float64)
# mse: tf.Tensor(2729.4568568184272, shape=(), dtype=float64)
# mape: tf.Tensor(29.600745647614055, shape=(), dtype=float64)
# mae: tf.Tensor(35.62463278635409, shape=(), dtype=float64)
# mse: tf.Tensor(2726.396994049068, shape=(), dtype=float64)
# mape: tf.Tensor(29.56253628159242, shape=(), dtype=float64)
# mae: tf.Tensor(35.09705931984037, shape=(), dtype=float64)
# mse: tf.Tensor(2695.535626484047, shape=(), dtype=float64)
# mape: tf.Tensor(29.326805227424458, shape=(), dtype=float64)
# mae: tf.Tensor(34.83601993444923, shape=(), dtype=float64)
# mse: tf.Tensor(2683.1865631363535, shape=(), dtype=float64)
# mape: tf.Tensor(29.394635300799724, shape=(), dtype=float64)
# mae: tf.Tensor(34.863076070145944, shape=(), dtype=float64)
# mse: tf.Tensor(2684.183341981716, shape=(), dtype=float64)
# mape: tf.Tensor(29.36325396839721, shape=(), dtype=float64)
# mae: tf.Tensor(34.83605526217437, shape=(), dtype=float64)
# mse: tf.Tensor(2682.352986593748, shape=(), dtype=float64)
# mape: tf.Tensor(29.330592967504636, shape=(), dtype=float64)
# mae: tf.Tensor(34.89742345474423, shape=(), dtype=float64)
# mse: tf.Tensor(2688.317836194971, shape=(), dtype=float64)
# mape: tf.Tensor(29.537886988725774, shape=(), dtype=float64)
# mae: tf.Tensor(34.87676162490644, shape=(), dtype=float64)
# mse: tf.Tensor(2685.888958841982, shape=(), dtype=float64)
# mape: tf.Tensor(29.44226442591117, shape=(), dtype=float64)
# mae: tf.Tensor(34.75860978529011, shape=(), dtype=float64)
# mse: tf.Tensor(2678.60162190962, shape=(), dtype=float64)
# mape: tf.Tensor(29.34812930381344, shape=(), dtype=float64)
# mae: tf.Tensor(34.5370022787899, shape=(), dtype=float64)
# mse: tf.Tensor(2668.587843471159, shape=(), dtype=float64)
# mape: tf.Tensor(29.4349885248321, shape=(), dtype=float64)
# mae: tf.Tensor(34.543614339276964, shape=(), dtype=float64)
# mse: tf.Tensor(2670.168196597628, shape=(), dtype=float64)
# mape: tf.Tensor(29.523173161079132, shape=(), dtype=float64)
# mae: tf.Tensor(34.85067564118066, shape=(), dtype=float64)
# mse: tf.Tensor(2691.1911066327834, shape=(), dtype=float64)
# mape: tf.Tensor(29.915509365415055, shape=(), dtype=float64)
# mae: tf.Tensor(34.818749436790974, shape=(), dtype=float64)
# mse: tf.Tensor(2692.5770185347033, shape=(), dtype=float64)
# mape: tf.Tensor(30.127206042315382, shape=(), dtype=float64)
# mae: tf.Tensor(35.053504014882634, shape=(), dtype=float64)
# mse: tf.Tensor(2708.7593866212924, shape=(), dtype=float64)
# mape: tf.Tensor(30.44704837784266, shape=(), dtype=float64)
# mae: tf.Tensor(34.97630085029628, shape=(), dtype=float64)
# mse: tf.Tensor(2702.896050970544, shape=(), dtype=float64)
# mape: tf.Tensor(30.28597154389773, shape=(), dtype=float64)
# mae: tf.Tensor(34.83766051233821, shape=(), dtype=float64)
# mse: tf.Tensor(2697.2854974787265, shape=(), dtype=float64)
# mape: tf.Tensor(30.390166131944824, shape=(), dtype=float64)
# mae: tf.Tensor(34.87982749502933, shape=(), dtype=float64)
# mse: tf.Tensor(2703.108052819107, shape=(), dtype=float64)
# mape: tf.Tensor(30.653184832499043, shape=(), dtype=float64)
# mae: tf.Tensor(35.42090074140069, shape=(), dtype=float64)
# mse: tf.Tensor(2741.83177573709, shape=(), dtype=float64)
# mape: tf.Tensor(31.40908328383828, shape=(), dtype=float64)
# mae: tf.Tensor(36.33690770945349, shape=(), dtype=float64)
# mse: tf.Tensor(2809.8257605156477, shape=(), dtype=float64)
# mape: tf.Tensor(32.398883858645235, shape=(), dtype=float64)
# mae: tf.Tensor(37.31769066997318, shape=(), dtype=float64)
# mse: tf.Tensor(2884.3778976563076, shape=(), dtype=float64)
# mape: tf.Tensor(33.55463570412316, shape=(), dtype=float64)
# mae: tf.Tensor(38.24564635382167, shape=(), dtype=float64)
# mse: tf.Tensor(2958.3370011480197, shape=(), dtype=float64)
# mape: tf.Tensor(34.575193663762086, shape=(), dtype=float64)
# mae: tf.Tensor(38.51703526256227, shape=(), dtype=float64)
# mse: tf.Tensor(2978.1001970540183, shape=(), dtype=float64)
# mape: tf.Tensor(34.9552732523363, shape=(), dtype=float64)
# mae: tf.Tensor(38.59153847817031, shape=(), dtype=float64)
# mse: tf.Tensor(2984.08544853439, shape=(), dtype=float64)
# mape: tf.Tensor(35.061232995167714, shape=(), dtype=float64)
# mae: tf.Tensor(38.52840749086638, shape=(), dtype=float64)
# mse: tf.Tensor(2974.0740434151126, shape=(), dtype=float64)
# mape: tf.Tensor(35.121737073392296, shape=(), dtype=float64)
# mae: tf.Tensor(39.613104776032465, shape=(), dtype=float64)
# mse: tf.Tensor(3059.7544928991847, shape=(), dtype=float64)
# mape: tf.Tensor(36.26560433260517, shape=(), dtype=float64)
# mae: tf.Tensor(40.7082470334381, shape=(), dtype=float64)
# mse: tf.Tensor(3151.28546174407, shape=(), dtype=float64)
# mape: tf.Tensor(37.305743033631394, shape=(), dtype=float64)
# mae: tf.Tensor(41.19285163617972, shape=(), dtype=float64)
# mse: tf.Tensor(3191.008067624685, shape=(), dtype=float64)
# mape: tf.Tensor(37.780884860869335, shape=(), dtype=float64)
# mae: tf.Tensor(42.390802675344204, shape=(), dtype=float64)
# mse: tf.Tensor(3290.7761685445, shape=(), dtype=float64)
# mape: tf.Tensor(38.931505388124776, shape=(), dtype=float64)
# mae: tf.Tensor(42.09420500207815, shape=(), dtype=float64)
# mse: tf.Tensor(3264.732437797432, shape=(), dtype=float64)
# mape: tf.Tensor(38.67454177332466, shape=(), dtype=float64)
# mae: tf.Tensor(42.06017199915482, shape=(), dtype=float64)
# mse: tf.Tensor(3261.337329607545, shape=(), dtype=float64)
# mape: tf.Tensor(38.6520202208769, shape=(), dtype=float64)
# mae: tf.Tensor(42.96993051831908, shape=(), dtype=float64)
# mse: tf.Tensor(3332.8934009038994, shape=(), dtype=float64)
# mape: tf.Tensor(39.61717182527302, shape=(), dtype=float64)
# mae: tf.Tensor(44.53858211482753, shape=(), dtype=float64)
# mse: tf.Tensor(3464.5992618534747, shape=(), dtype=float64)
# mape: tf.Tensor(41.101633912782866, shape=(), dtype=float64)
# mae: tf.Tensor(45.91719879706105, shape=(), dtype=float64)
# mse: tf.Tensor(3587.571096795093, shape=(), dtype=float64)
# mape: tf.Tensor(42.32470906015014, shape=(), dtype=float64)
# mae: tf.Tensor(46.39747317251431, shape=(), dtype=float64)
# mse: tf.Tensor(3628.8548674288345, shape=(), dtype=float64)
# mape: tf.Tensor(42.778320639997354, shape=(), dtype=float64)
# mae: tf.Tensor(47.499050329306044, shape=(), dtype=float64)
# mse: tf.Tensor(3727.5299757452904, shape=(), dtype=float64)
# mape: tf.Tensor(43.75588223886919, shape=(), dtype=float64)
# mae: tf.Tensor(48.727547381226884, shape=(), dtype=float64)
# mse: tf.Tensor(3835.478379531156, shape=(), dtype=float64)
# mape: tf.Tensor(44.888679634307856, shape=(), dtype=float64)
# mae: tf.Tensor(48.81270221254511, shape=(), dtype=float64)
# mse: tf.Tensor(3840.4759111495987, shape=(), dtype=float64)
# mape: tf.Tensor(44.9924285922037, shape=(), dtype=float64)
# mae: tf.Tensor(49.1701896111056, shape=(), dtype=float64)
# mse: tf.Tensor(3865.1216821904195, shape=(), dtype=float64)
# mape: tf.Tensor(45.370907535893835, shape=(), dtype=float64)
# mae: tf.Tensor(51.45627337352195, shape=(), dtype=float64)
# mse: tf.Tensor(4070.6911879914246, shape=(), dtype=float64)
# mape: tf.Tensor(47.40892906180082, shape=(), dtype=float64)
# mae: tf.Tensor(51.34970635294849, shape=(), dtype=float64)
# mse: tf.Tensor(4061.0078743942513, shape=(), dtype=float64)
# mape: tf.Tensor(47.314728122469845, shape=(), dtype=float64)
# mae: tf.Tensor(50.83788857200755, shape=(), dtype=float64)
# mse: tf.Tensor(4014.6031176029815, shape=(), dtype=float64)
# mape: tf.Tensor(46.86070557953341, shape=(), dtype=float64)
# mae: tf.Tensor(49.66998366825329, shape=(), dtype=float64)
# mse: tf.Tensor(3913.765680981888, shape=(), dtype=float64)
# mape: tf.Tensor(45.79613298844532, shape=(), dtype=float64)
# mae: tf.Tensor(47.81964296660543, shape=(), dtype=float64)
# mse: tf.Tensor(3756.4665006450696, shape=(), dtype=float64)
# mape: tf.Tensor(44.07308739976986, shape=(), dtype=float64)
# mae: tf.Tensor(45.27100615606617, shape=(), dtype=float64)
# mse: tf.Tensor(3543.559875697022, shape=(), dtype=float64)
# mape: tf.Tensor(41.6112716549059, shape=(), dtype=float64)
# mae: tf.Tensor(44.860086879733416, shape=(), dtype=float64)
# mse: tf.Tensor(3503.9347549488675, shape=(), dtype=float64)
# mape: tf.Tensor(41.267316798740765, shape=(), dtype=float64)
# mae: tf.Tensor(44.825783129190086, shape=(), dtype=float64)
# mse: tf.Tensor(3496.978899114412, shape=(), dtype=float64)
# mape: tf.Tensor(41.28409784620419, shape=(), dtype=float64)
# mae: tf.Tensor(44.856165219255004, shape=(), dtype=float64)
# mse: tf.Tensor(3500.8030586056057, shape=(), dtype=float64)
# mape: tf.Tensor(41.277501446611005, shape=(), dtype=float64)
# mae: tf.Tensor(44.05755232036771, shape=(), dtype=float64)
# mse: tf.Tensor(3427.3253532411895, shape=(), dtype=float64)
# mape: tf.Tensor(40.595001463735976, shape=(), dtype=float64)
# mae: tf.Tensor(44.76901157386983, shape=(), dtype=float64)
# mse: tf.Tensor(3489.2931138522413, shape=(), dtype=float64)
# mape: tf.Tensor(41.23351634266617, shape=(), dtype=float64)
# mae: tf.Tensor(44.2576588413508, shape=(), dtype=float64)
# mse: tf.Tensor(3447.6289193596494, shape=(), dtype=float64)
# mape: tf.Tensor(40.74719101564791, shape=(), dtype=float64)
# mae: tf.Tensor(43.87862627555322, shape=(), dtype=float64)
# mse: tf.Tensor(3416.598047467108, shape=(), dtype=float64)
# mape: tf.Tensor(40.36530535441303, shape=(), dtype=float64)
# mae: tf.Tensor(44.646610567262144, shape=(), dtype=float64)
# mse: tf.Tensor(3476.208578357948, shape=(), dtype=float64)
# mape: tf.Tensor(41.1778833199599, shape=(), dtype=float64)
# mae: tf.Tensor(45.649269198619955, shape=(), dtype=float64)
# mse: tf.Tensor(3561.6200701372422, shape=(), dtype=float64)
# mape: tf.Tensor(42.110624079008645, shape=(), dtype=float64)
# mae: tf.Tensor(46.069905457766005, shape=(), dtype=float64)
# mse: tf.Tensor(3598.288276944732, shape=(), dtype=float64)
# mape: tf.Tensor(42.495549633727684, shape=(), dtype=float64)
# mae: tf.Tensor(45.20456268680682, shape=(), dtype=float64)
# mse: tf.Tensor(3523.3064222880957, shape=(), dtype=float64)
# mape: tf.Tensor(41.7036985875238, shape=(), dtype=float64)
# mae: tf.Tensor(44.99708094829931, shape=(), dtype=float64)
# mse: tf.Tensor(3505.0856993532425, shape=(), dtype=float64)
# mape: tf.Tensor(41.51013749969629, shape=(), dtype=float64)
# mae: tf.Tensor(44.17196408989364, shape=(), dtype=float64)
# mse: tf.Tensor(3438.2334532292602, shape=(), dtype=float64)
# mape: tf.Tensor(40.70633185664595, shape=(), dtype=float64)
# mae: tf.Tensor(43.7367906180126, shape=(), dtype=float64)
# mse: tf.Tensor(3404.9197067146188, shape=(), dtype=float64)
# mape: tf.Tensor(40.235521885309886, shape=(), dtype=float64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 36
#      33     # PLOT ----------------------------------------------------------------------------------------------------------
#      34     # plot models
#      35 plt.figure(figsize=(20, 10))
# ---> 36 plt.plot(pd.DataFrame(y_test), label='True Values', linewidth=2.5)
#      37 plt.plot(pd.DataFrame(yhat_arima), label='Pred. GRU', linestyle='--')
#      38 plt.xlabel('Time')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:785, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     774         mgr = dict_to_mgr(
#     775             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     776             # attribute "name"
#    (...)
#     782             copy=_copy,
#     783         )
#     784     else:
# --> 785         mgr = ndarray_to_mgr(
#     786             data,
#     787             index,
#     788             columns,
#     789             dtype=dtype,
#     790             copy=copy,
#     791             typ=manager,
#     792         )
#     794 # For data is list-like, or Iterable (will consume into list)
#     795 elif is_list_like(data):
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:314, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     308     _copy = (
#     309         copy_on_sanitize
#     310         if (dtype is None or astype_is_view(values.dtype, dtype))
#     311         else False
#     312     )
#     313     values = np.array(values, copy=_copy)
# --> 314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
#     319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=(718, 7, 1)

# %%
# default libs
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Forcesting libs
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from pandas.plotting import register_matplotlib_converters

# default lib for ignore warinigs
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# This summarizes the coefficient values used as well as the skill of the fit on the on the in-sample observations.
# Non-seasonal ARIMA models are generally denoted ARIMA(p,d,q) where parameters p, d, and q are non-negative integers, p is the order (number of time lags) of the auto-regressive model, d is the degree of differencing (the number of times the data have had past values subtracted), and q is the order of the moving-average model. Seasonal ARIMA models are usually denoted ARIMA(p,d,q)(P,D,Q)m, where m refers to the number of periods in each season, and the uppercase P,D,Q refer to the auto-regressive, differencing, and moving average terms for the seasonal part of the ARIMA model.

# %%
from statsmodels.graphics.tsaplots import plot_acf
series = smoothed[['timeseries_350']]

arima_model = ARIMA(series.values, order=(2,1,3))
model = arima_model.fit()
print(model.summary())

# Get the predicted values
predictions = model.predict(start=0, end=len(series) - 1, typ='levels')

# %%
# Plot actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(series['I10'].values, label='Actual')
plt.plot(predictions, label='Predicted', linestyle='--')
plt.legend()
plt.title('Actual vs. Predicted Values')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
